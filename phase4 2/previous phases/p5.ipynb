# %%
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException 
import numpy as np

# %%
### Links for each page of Face Moisturizer 

# driver.get('https://www.ulta.com/skin-care-face-moisturizer?N=27h9')
# driver.get('https://www.ulta.com/skin-care-face-moisturizer?N=27h9&No=96&Nrpp=96')
# driver.get('https://www.ulta.com/skin-care-face-moisturizer?N=27h9&No=192&Nrpp=96')
# driver.get('https://www.ulta.com/skin-care-face-moisturizer?N=27h9&No=288&Nrpp=96') 
# driver.get('https://www.ulta.com/skin-care-face-moisturizer?N=27h9&No=384&Nrpp=96') 
# driver.get(https://www.ulta.com/skin-care-face-moisturizer?N=27h9&No=480&Nrpp=96')

# %%
### Get Chrome Driver Path 
path = r"C:\Users\avach\Downloads\clone\info2950\chromedriver.exe" 
driver = webdriver.Chrome(path) 

### Open Ulta Moisturizer Site
driver.get('https://www.ulta.com/skin-care-face-moisturizer?N=27h9&No=384&Nrpp=96')

# %%
all_prod = driver.find_element_by_xpath('//*[@id="product-category-cont"]')

html_list = all_prod.find_element_by_id("foo16")
all_li = html_list.find_elements_by_tag_name("li")

product_name = []
subpageurl = []


#append links for products to subpageurl list
for li in all_li: 
    first_atag = li.find_element_by_tag_name('a')
    product_links= first_atag.get_attribute('href')
    
#popup link, got rid of it 
    if product_links != 'http://www.ulta.com/ulta/creditcards/landingpage.jsp':
        subpageurl.append(product_links)
        
#get name of hyperlink, not actual link 

#https://sqa.stackexchange.com/questions/37024/how-do-i-get-the-text-of-a-hyperlink-not-the-actual-link-using-selenium-and-py (innerlink source)
        cut_text = first_atag.get_attribute('innerHTML')
        find_alt = cut_text.find('alt="')
        name = cut_text[find_alt+5:]
        find_border = name.find('" border=')
        name2 = name[:find_border]
        if '+' in name2: 
            plus = name2.find('+') 
            name2 = name2[:plus]
            
        product_name.append(name2)

# %%
brand_list = []
product_list = [] 
price_list = [] 
rating_list = []
ingredient_list = []

# %%
##loop to get info on first page 

for link in subpageurl:
    driver.get(link)  

    ## Get brand 
    try:
        brand_list.append(driver.find_element_by_xpath('//*[@id="js-mobileBody"]/div/div/div/div/div/div/section[1]/div[2]/div/h1/div[1]').text)
    except: 
        brand_list.append('NA')
    
    ### Get Product Name 
    try:
        product_list.append(driver.find_element_by_xpath('//*[@id="js-mobileBody"]/div/div/div/div/div/div/section[1]/div[2]/div/h1/div[2]').text)
    except: 
        product_list.append('NA')
     ### Get Price 
    try:
        price_list.append(driver.find_element_by_xpath('//*[@id="js-mobileBody"]/div/div/div/div/div/div/section[1]/div[2]/div/div[3]').text)
    except: 
        price_list.append('NA') 
        
    ### Get Rating Number 
    try: 
        rating_list.append(driver.find_element_by_xpath('//*[@id="pr-review-snapshot"]/header/section/div/div[1]/div/div[1]/div').text)
    except: 
        rating_list.append('NA')

    ### Once on product page, toggle ingredients and get text
    try:
        toggle = driver.find_element_by_xpath('//*[@id="productDescription"]/div[3]/div[2]')
        toggle.click() 

        ingredient_list.append(driver.find_element_by_xpath('//*[@id="productDescription"]/div[3]/div[2]/div[2]/div/div/div').text) 
    except:
        ingredient_list.append('NA')

# %%
ulta_moisturizer_df = pd.DataFrame(
    {'brand': brand_list[:96],
     'name': product_list[:96],
     'price': price_list[:96],
     'rating': rating_list[:96],
     'ingredients': ingredient_list[:96]
    }) 

pd.set_option('display.max_rows',None)
ulta_moisturizer_df
#ulta_moisturizer_df_keep=ulta_moisturizer_df.copy()
# Out:
#                  brand                                               name  \
# 0              Garnier  Green Labs Canna-B Pore Perfecting Serum Cream...
# 1       Formula 10.0.6             Picture Perfect Day Moisturizer SPF 15
# 2      Elizabeth Arden    Eight Hour Cream Skin Protectant Fragrance Free
# 3               Aveeno             Ultra-Calming Daily Moisturizer SPF 30
# 4             Botanics                   Simply Calm Hydrating Face Cream
# 5       Formula 10.0.6        Hold Tight Vitamin B Smoothing Daily Primer
# 6             Clinique    Dramatically Different Hydrating Clearing Jelly
# 7                belif                            Hungarian Water Essence
# 8           My Clarins                RE-BOOST Refreshing Hydrating Cream
# 9           Neutrogena  Travel Size Rapid Wrinkle Repair Regenerating ...
# 10         Dermalogica             Travel Size Intensive Moisture Balance
# 11   Peter Thomas Roth   Hungarian Thermal Water Mineral-Rich Moisturizer
# 12               Tarte  Double Duty Beauty First Step Prep Moisture Re...
# 13            cocokind                            Texture Smoothing Cream
# 14             L'Oréal  Revitalift Anti-Wrinkle + Firming Face & Neck ...
# 15            Pacifica                    Cosmic Hemp CBD Everything Balm
# 16             Follain                   Moisturizer: Replenish + Protect
# 17       Mario Badescu                        Oil Free Moisturizer SPF 17
# 18            Clinique  Clinique Smart Clinical MD Multi-Dimensional A...
# 19        PEACH & LILY       Travel Size Glass Skin Water-Gel Moisturizer
# 20  Kiehl's Since 1851                Super Multi Corrective Cream SPF 30
# 21               Vichy  LiftActiv Retinol HA Anti-Wrinkle Concentrate ...
# 22    Andalou Naturals                             DMAE Lift & Firm Cream
# 23            Clinique  Travel Size Moisture Surge Hydrating Superchar...
# 24        Juice Beauty                               Nutrient Moisturizer
# 25        Perricone MD  Hypoallergenic CBD Sensitive Skin Therapy Nour...
# 26            Clinique     Even Better Skin Tone Correcting Lotion SPF 20
# 27         Dermalogica                                         Power Rich
# 28            TONYMOLY           Panda's Dream Rose Hyaluronic Face Cream
# 29       Mario Badescu                              Cellufirm Moisturizer
# 30         LOLI Beauty  Chia Carrot Brûlée Organic Revitalizing All-Ov...
# 31            Clinique  Travel Size Dramatically Different Hydrating J...
# 32                Pixi                                Rose Ceramide Cream
# 33               Curél                               Moisture Facial Milk
# 34            Clinique  Clinique For Men Anti-Fatigue Hydrating Concen...
# 35       Honest Beauty                            Magic Beauty Balm Stick
# 36            cocokind                            MyMatcha Moisture Stick
# 37                Olay              Total Effects Whip Moisturizer SPF 40
# 38               ACURE            Radically Rejuvenating SPF 30 Day Cream
# 39             Clarins                        Super Restorative Day Cream
# 40         W3LL PEOPLE      Bio Tint Multi-Action Moisturizer with SPF 30
# 41      Carbon Theory.  Vitamin E & Tea Tree Oil Breakout Control Faci...
# 42              KORRES  White Pine Meno-Reverse Volumizing Serum-in-Mo...
# 43          Dr. Brandt        Cool Biotic Pre-Biotic Redness Relief Cream
# 44            Skinfood                                Peach Sake Emulsion
# 45         Dermalogica                   Travel Size Skin Smoothing Cream
# 46            Proactiv                                T-Zone Oil Absorber
# 47               belif                                  Milky Moisturizer
# 48          Philosophy                     Purity Made Simple Moisturizer
# 49             Garnier  Green Labs Hyalu-Melon Replumping Serum Cream ...
# 50            Clinique  Clinique iD Dramatically Different For Uneven ...
# 51     Alpha Skin Care                             Enhanced Renewal Cream
# 52           Exuviance                  Glycolic Expert Daily Moisturizer
# 53               Tarte               Knockout Brightening Gel Moisturizer
# 54          Neutrogena                 Combination Skin Oil-Free Moisture
# 55     Kate Somerville                   KateCeuticals Total Repair Cream
# 56           Exuviance              Glycolic Perfecting Night Moisturizer
# 57               ACURE                Seriously Soothing SPF 30 Day Cream
# 58          Jack Black                   Clean Break Oil-Free Moisturizer
# 59             Clarins                                Rose Radiance Cream
# 60              ELEMIS               Dynamic Resurfacing Day Cream SPF 30
# 61          Neutrogena                           Oil-Free Moisture SPF 15
# 62       Honest Beauty                                    Dew Wonders Kit
# 63       Honest Beauty                               Deep Hydration Cream
# 64              Aveeno                                  Daily Moisturizer
# 65               Truly                      Cream Skin Facial Moisturizer
# 66               Avène                 TriXera Nutrition Nutri-Fluid Balm
# 67               ACURE         Ultra Hydrating 12 Hour Facial Moisturizer
# 68          bioClarity       Primed & Ready 2-in-1 Moisturizer and Primer
# 69  Kiehl's Since 1851  Clearly Corrective Brightening Smoothing Moist...
# 70          Neutrogena                             Bright Boost Gel Cream
# 71            Pacifica            Cosmic Shield Hydration Lock Face Cream
# 72            Clinique    Travel Size Dramatically Different Oil-Free Gel
# 73           BeautyBio                  The ZenBubble Calming Skin Shield
# 74               Avène                 RICH Revitalizing Nourishing Cream
# 75      Formula 10.0.6  Seriously Shine Free Mattifying Oil Free Moist...
# 76               Avène                          Moisturizing Melt-In Balm
# 77         Dermalogica                  Travel Size Prisma Protect SPF 30
# 78       Mario Badescu                         The Moisture Magnet SPF 15
# 79          Neutrogena          Pink Grapefruit Oil-Free Acne Moisturizer
# 80               Oh K!                      Chok Chok Glowing Moisturiser
# 81             Hanskin                      Vitamin C Glow Capsule Lotion
# 82    Andalou Naturals            Ultra Sheer Daily Defense Facial Lotion
# 83   Peter Thomas Roth          Vital-E Microbiome Moisture Defense Cream
# 84             Garnier    SkinActive Moisture Rescue Refreshing Gel-Cream
# 85             Origins              GinZing Glow-Boosting Gel Moisturizer
# 86             Lancôme  Bienfait Multi-Vital Eye Sunscreen Broad Spect...
# 87            Skinfood                        Peach Jelly Soothing Gel 90
# 88               ACURE                     Seriously Soothing Cloud Cream
# 89          Dr. Brandt                            Hyaluronic Facial Cream
# 90        Juice Beauty                Prebiotix Hydrating Gel Moisturizer
# 91             Garnier           SkinActive Water Rose 24H Moisture Cream
# 92    ArtNaturals LUXE                              Hydrating Moisturizer
# 93            NUDESTIX         NUDESKIN Citrus-C Mask & Daily Moisturizer
# 94               belif                       Problem Solution Moisturizer
# 95              boscia                           Chia Seed Moisture Cream
#
#                                          price rating  \
# 0   Sale Price\n$15.39\nOriginal Price\n$21.99    4.5
# 1     Sale Price\n$5.24\nOriginal Price\n$7.49    3.8
# 2                                  Online Only    4.5
# 3   Sale Price\n$15.99\nOriginal Price\n$19.99    4.2
# 4   Sale Price\n$12.59\nOriginal Price\n$17.99    4.5
# 5                                Price\n$15.00    4.7
# 6                                Price\n$16.00    4.4
# 7                                Price\n$42.00    4.4
# 8                                Price\n$26.00    4.5
# 9   Sale Price\n$11.19\nOriginal Price\n$13.99    4.3
# 10                               Price\n$16.50    4.5
# 11                               Price\n$58.00      4
# 12                         Only at Ulta Beauty    4.6
# 13                                 Online Only    4.3
# 14  Sale Price\n$14.39\nOriginal Price\n$17.99    4.1
# 15                         Only at Ulta Beauty    4.7
# 16                               Price\n$32.00    4.8
# 17                               Price\n$24.00    4.2
# 18                               Price\n$69.00    4.5
# 19                         Only at Ulta Beauty     NA
# 20                               Price\n$68.00    3.6
# 21                                 Online Only    4.4
# 22                                 Online Only    4.7
# 23                               Price\n$14.00    4.5
# 24                               Price\n$42.00    3.7
# 25                               Price\n$75.00    4.6
# 26                               Price\n$53.00    3.3
# 27                              Price\n$190.00    4.5
# 28  Sale Price\n$12.95\nOriginal Price\n$18.50    4.5
# 29                               Price\n$18.00    4.4
# 30                                 Online Only      5
# 31                                Price\n$5.50    4.3
# 32  Sale Price\n$16.80\nOriginal Price\n$24.00    4.8
# 33  Sale Price\n$21.00\nOriginal Price\n$30.00    4.7
# 34                               Price\n$46.00    4.3
# 35                                 Online Only    4.3
# 36                                 Online Only    4.7
# 37  Sale Price\n$27.29\nOriginal Price\n$38.99    4.6
# 38  Sale Price\n$13.29\nOriginal Price\n$18.99      3
# 39                              Price\n$129.00    4.7
# 40                                 Online Only    4.2
# 41                         Only at Ulta Beauty    4.7
# 42                               Price\n$58.00    3.5
# 43                               Price\n$55.00    4.7
# 44                                 Online Only    4.5
# 45                               Price\n$16.00    4.5
# 46  Sale Price\n$15.00\nOriginal Price\n$30.00      4
# 47                                 Online Only    4.6
# 48                               Price\n$14.00    4.5
# 49  Sale Price\n$15.39\nOriginal Price\n$21.99    4.4
# 50                               Price\n$39.50    3.1
# 51                                 Online Only    4.7
# 52                               Price\n$46.00    4.2
# 53                               Price\n$39.00    3.3
# 54  Sale Price\n$11.99\nOriginal Price\n$14.99     NA
# 55                                 Online Only     NA
# 56                               Price\n$47.00    4.7
# 57  Sale Price\n$13.29\nOriginal Price\n$18.99    3.3
# 58                               Price\n$30.00    4.7
# 59                              Price\n$129.00    4.2
# 60                                 Online Only    4.8
# 61  Sale Price\n$11.99\nOriginal Price\n$14.99    3.6
# 62                                 Online Only    4.7
# 63                                 Online Only     NA
# 64  Sale Price\n$15.99\nOriginal Price\n$19.99     NA
# 65                         Only at Ulta Beauty    3.5
# 66                                 Online Only    4.8
# 67  Sale Price\n$13.29\nOriginal Price\n$18.99      4
# 68                         Only at Ulta Beauty    4.7
# 69                                 Online Only    4.2
# 70  Sale Price\n$21.59\nOriginal Price\n$26.99     NA
# 71  Sale Price\n$11.20\nOriginal Price\n$16.00     NA
# 72                                Price\n$5.50     NA
# 73                               Price\n$65.00    4.7
# 74                                 Online Only      5
# 75    Sale Price\n$5.24\nOriginal Price\n$7.49     NA
# 76                                 Online Only     NA
# 77                               Price\n$19.00      4
# 78                               Price\n$24.00     NA
# 79   Sale Price\n$8.79\nOriginal Price\n$10.99    3.9
# 80  Sale Price\n$10.50\nOriginal Price\n$15.00    4.4
# 81                         Only at Ulta Beauty      5
# 82                                 Online Only    4.4
# 83                               Price\n$75.00    4.2
# 84    Sale Price\n$6.29\nOriginal Price\n$8.99    4.4
# 85                               Price\n$32.00      4
# 86                               Price\n$45.00    3.9
# 87                                 Online Only    4.5
# 88  Sale Price\n$13.29\nOriginal Price\n$18.99    4.2
# 89                               Price\n$72.00    4.6
# 90                               Price\n$52.00    4.2
# 91  Sale Price\n$10.49\nOriginal Price\n$14.99    4.7
# 92                         Only at Ulta Beauty    4.8
# 93                                 Online Only    4.6
# 94                               Price\n$38.00    4.4
# 95                               Price\n$38.00    4.5
#
#                                           ingredients
# 0   Active: Avobenzone 3%, Homosalate 5%, Octisala...
# 1   Active: Avobenzone 2.0%, Octocrylene 6.0%, Sal...
# 2   Petrolatum, Lanolin, Mineral Oil / Paraffinum ...
# 3   Active: Titanium Oxide (4.3%), Zinc Oxide (3%)...
# 4   Aqua (Water), Glycerin, Ethylhexyl Palmitate, ...
# 5   Cyclopentasiloxane, Dimethicone Crosspolymer, ...
# 6   Water\Aqua\Eau, Propanediol, Glycerin, Butylen...
# 7   Water, Dipropylene Glycol, Glycerin, 1,2-Hexan...
# 8   Aqua/Water/Eau, Caprylic/Capric Triglyceride, ...
# 9
# 10  Water, Ethylhexyl Hydroxystearate, Butylene Gl...
# 11  Water/Aqua/Eau, Dimethicone, Peg/Ppg-18/18 Dim...
# 12  Water/Aqua/Eau, Octyldodecyl Neopentanoate, Ca...
# 13  Water, Cucumis Sativus (Cucumber) Fruit Water,...
# 14  Aqua / Water, Cyclohexasiloxane, Glycerin, Par...
# 15  Cocos Nucifera (Coconut) Oil, Helianthus Annuu...
# 16  Water/Aqua/Eau, Glycerin, Aloe Barbadensis Lea...
# 17  Active: Avobenzone 2%, Octinoxate 7.5%, Oxyben...
# 18  Water\Aqua\Eau, Butylene Glycol, Butyrospermum...
# 19  Water (Aqua), Glycerin, Propanediol, 1,2-Hexan...
# 20  Aqua/Water, Glycerin, Dicaprylyl Ether, Butyro...
# 21  Aqua /Water, Glycerin, Dicaprylyl Ether, Isopr...
# 22  Aloe Barbadensis Leaf Juice*, Purified Water (...
# 23  Water\Aqua\Eau, Glycerin, Butylene Glycol, Phe...
# 24  Organic juices of vitis vinifera (Organic Whit...
# 25  This item is not eligible for coupon discounts...
# 26  Active: Octisalate 5.00%, Avobenzone 3.00%, Oc...
# 27  Water/Aqua/Eau, Cyclopentasiloxane, Methylhept...
# 28  Water, Butylene Glycol, Dipropylene Glycol, Di...
# 29  Aqua (Water, Eau), Propylene Glycol, Paraffinu...
# 30  Salvia Hispanica (Chia) Seed Oil*, Garcinia In...
# 31  Water\Aqua\Eau Water\Aqua\Eau, Bis-PEG-18 Meth...
# 32  Aqua/Water/Eau, Dipropylene Glycol, Glycerin, ...
# 33  Water/Aqua, Glycerin, Cetyl-PG Hydroxyethyl Pa...
# 34  Active: Avobenzone 3.0%, Octisalate 5.0%\nInac...
# 35  Helianthus Annuus (sunflower) Seed Oil, Cocos ...
# 36  Cocos (coconut) Nucifera Oil*, Beeswax*, Camel...
# 37  Active: Avobenzone 3.0%, Homosalate 10.0%, Oct...
# 38  Active: Zinc Oxide 15%. Inactive: Allantoin, A...
# 39  Acetyl Tetrapeptide-2, Aqua/Water/Eau, Ascorby...
# 40  Active: Zinc Oxide 20%. Inactive: Water, Coco-...
# 41  Aqua (Water), Cetearyl Alcohol, Helianthus Ann...
# 42  Aqua/Water/Eau, Glycerin, Caprylic/Capric Trig...
# 43  Water/Aqua/Eau, Caprylic/Capric Triglyceride, ...
# 44  Water, Phenyl Trimethicone, Alcohol Denat., Mi...
# 45  Water, Caprylic/Capric Triglyceride, Methyl Gl...
# 46  Mattifying Complex: a skin conditioning techno...
# 47  Water, Dipropylene Glycol, Glycerin, Triethylh...
# 48  Aqua/Water/Eau, Cyclopentasiloxane, Bis-PEG-18...
# 49  Active: Avobenzone 3%, Homosalate 5%, Octisala...
# 50  Clinique iD Active Cartridge Concentrate for U...
# 51  Water, Glycolic Acid, Ammonium Hydroxide, Cety...
# 52  Aqua/water/eau, Glycolic Acid, Butylene Glycol...
# 53  Water/Aqua/Eau, Citrus Tangerina (Tangerine) F...
# 54  Water, Cyclomethicone, Cetyl Ethylhexanoate, G...
# 55  Aqua/Water/Eau, Cetearyl Alcohol, Dimethicone,...
# 56  Aqua/water/eau, Glycolic Acid, C12-15 Alkyl Be...
# 57  Active: Zinc Oxide 15%. Inactive: Allantoin, A...
# 58  Aqua (Water/Eau), Cyclopentasiloxane, Octyldod...
# 59  Aqua/Water/Eau, Glycerin, Corylus Avellana (Ha...
# 60  Aqua/Water/Eau, Coco-Caprylate, Glycerin, Capr...
# 61  Active: Avobenzone (1.5%), Octisalate (5%), Oc...
# 62  Prime + Perfect Mask: Water (Aqua), Glycerin, ...
# 63  Water (Aqua), Ethylhexyl Stearate, Glycerin, R...
# 64  Active: Salicylic Acid 0.5%. Inactive: Arachid...
# 65                                                 NA
# 66  Avène Thermal Spring Water (Avène Aqua), Glyce...
# 67  Water (Aqua), Cetearylalcohol, Glyceryl Steara...
# 68  Aqua (Water, Eau), Dicaprylyl Carbonate, Hydro...
# 69  Aqua/Water, Dimethicone, Propylene Glycol, Gly...
# 70  Water, Dimethicone, Glycerin, Mandelic Acid, T...
# 71  Aqua, Simmondsia Chinensis (Jojoba) Seed Oil, ...
# 72  Water / Aqua / Eau, Dimethicone, Isododecane, ...
# 73  Water/Aqua/Eau, Glycerin, Dimethicone, Butylen...
# 74  Avène Thermal Spring Water (Avene Aqua), Butyr...
# 75  Water, Propylene Glycol, Butylene Glycol, Cete...
# 76  Avène Thermal Spring Water (avène Aqua), Glyce...
# 77  Water/Aqua/Eau, Homosalate, Octocrylene, Silic...
# 78  Avobenzone 3%, Octinoxate 7.5%, Oxybenzone 5%....
# 79  Active: Salicylic Acid 0.5%. Inactive: Water, ...
# 80                                                 NA
# 81  Water, Butylene Glycol, Octyldodecyl Myristate...
# 82  Aloe Barbadensis Juice*, Vegetable Glycerin, H...
# 83  Water/Aqua/Eau, Glycerin, Dimethicone, Methyl ...
# 84  Aqua/Water, Glycerin, Alcohol Denat., Dimethic...
# 85  Water\Aqua\Eau, Butylene Glycol, Dicaprylyl Ca...
# 86  This item is not eligible for coupon discounts...
# 87  Prunus Persica (Peach) Fruit Extract, Glycerin...
# 88  Water (Aqua), Persea Gratissima (Avocado) Oil,...
# 89  Water/Aqua/Eau, Butyrospermum Parkii (Shea) Bu...
# 90  Aloe Barbadensis (Organic Aloe Juice/Jus D¿alo...
# 91  Aqua/Water, Glycerin, Dimethicone, Cetearyl, E...
# 92  DI Water, Cetyl Ethylhexanoate, Glycerin, Prop...
# 93  Water (Aqua), Glycerin, Propanediol, Dipropyle...
# 94  Water, Glycerin, Glyceryl Stearate, Cetyl Ethy...
# 95  Water/Aqua/Eau, Glycerin, Butyrospermum Parkii...

# %%
ulta_moisturizer_df.to_csv('ulta_m5.csv', index = False)

# %%
### Find first product and click to open 
#prod = driver.find_element_by_xpath('//*[@id="xlsImpprod13641053"]/div[2]') 
#prod.click()

# %%
### Get brand
# brand = driver.find_element_by_xpath('//*[@id="js-mobileBody"]/div/div/div/div/div/div/section[1]/div[2]/div/h1/div[1]').text
# print(brand)

# ### Get Product Name 
# name = driver.find_element_by_xpath('//*[@id="js-mobileBody"]/div/div/div/div/div/div/section[1]/div[2]/div/h1/div[2]').text
# print(name) 
 

# ### Get Rating Number
# star = driver.find_element_by_xpath('//*[@id="pr-review-snapshot"]/header/section/div/div[1]/div/div[1]/div').text
# print(star) 

# ### Once on product page, toggle ingredients and get text
# toggle = driver.find_element_by_xpath('//*[@id="productDescription"]/div[3]/div[2]')
# toggle.click() 

# ingredient = driver.find_element_by_xpath('//*[@id="productDescription"]/div[3]/div[2]/div[2]/div/div/div').text
# print(ingredient) 

# ### Get Price 
# price = driver.find_element_by_xpath('//*[@id="js-mobileBody"]/div/div/div/div/div/div/section[1]/div[2]/div/div[3]').text
# print(price)

# %%
# def scrollDown(driver, n_scroll):

#     body = driver.find_element_by_tag_name("body")
#     while n_scroll >= 0:
#         body.send_keys(Keys.PAGE_DOWN)
#         n_scroll -= 1
#     return driver

# %%
##next steps 

#move into data frame 
#scrol through each of the 14 pages
