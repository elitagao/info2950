# %%
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException 
import numpy as np

# %%
### Links for each page of Face Moisturizer 

# driver.get('https://www.ulta.com/skin-care-face-moisturizer?N=27h9')
# driver.get('https://www.ulta.com/skin-care-face-moisturizer?N=27h9&No=96&Nrpp=96')
# driver.get('https://www.ulta.com/skin-care-face-moisturizer?N=27h9&No=192&Nrpp=96')
# driver.get('https://www.ulta.com/skin-care-face-moisturizer?N=27h9&No=288&Nrpp=96') 
# driver.get('https://www.ulta.com/skin-care-face-moisturizer?N=27h9&No=384&Nrpp=96') 
# driver.get('https://www.ulta.com/skin-care-face-moisturizer?N=27h9&No=480&Nrpp=96')

# %%
### Get Chrome Driver Path 
path = r"C:\Users\avach\Downloads\clone\info2950\chromedriver.exe" 
driver = webdriver.Chrome(path) 

### Open Ulta Moisturizer Site
driver.get('https://www.ulta.com/skin-care-face-moisturizer?N=27h9&No=480&Nrpp=96')

# %%
all_prod = driver.find_element_by_xpath('//*[@id="product-category-cont"]')

html_list = all_prod.find_element_by_id("foo16")
all_li = html_list.find_elements_by_tag_name("li")

product_name = []
subpageurl = []


#append links for products to subpageurl list
for li in all_li: 
    first_atag = li.find_element_by_tag_name('a')
    product_links= first_atag.get_attribute('href')
    
#popup link, got rid of it 
    if product_links != 'http://www.ulta.com/ulta/creditcards/landingpage.jsp':
        subpageurl.append(product_links)
        
#get name of hyperlink, not actual link 

#https://sqa.stackexchange.com/questions/37024/how-do-i-get-the-text-of-a-hyperlink-not-the-actual-link-using-selenium-and-py (innerlink source)
        cut_text = first_atag.get_attribute('innerHTML')
        find_alt = cut_text.find('alt="')
        name = cut_text[find_alt+5:]
        find_border = name.find('" border=')
        name2 = name[:find_border]
        if '+' in name2: 
            plus = name2.find('+') 
            name2 = name2[:plus]
            
        product_name.append(name2)

# %%
brand_list = []
product_list = [] 
price_list = [] 
rating_list = []
ingredient_list = []

# %%
##loop to get info on first page 

for link in subpageurl:
    driver.get(link)  

    ## Get brand 
    try:
        brand_list.append(driver.find_element_by_xpath('//*[@id="js-mobileBody"]/div/div/div/div/div/div/section[1]/div[2]/div/h1/div[1]').text)
    except: 
        brand_list.append('NA')
    
    ### Get Product Name 
    try:
        product_list.append(driver.find_element_by_xpath('//*[@id="js-mobileBody"]/div/div/div/div/div/div/section[1]/div[2]/div/h1/div[2]').text)
    except: 
        product_list.append('NA')
     ### Get Price 
    try:
        price_list.append(driver.find_element_by_xpath('//*[@id="js-mobileBody"]/div/div/div/div/div/div/section[1]/div[2]/div/div[3]').text)
    except: 
        price_list.append('NA') 
        
    ### Get Rating Number 
    try: 
        rating_list.append(driver.find_element_by_xpath('//*[@id="pr-review-snapshot"]/header/section/div/div[1]/div/div[1]/div').text)
    except: 
        rating_list.append('NA')

    ### Once on product page, toggle ingredients and get text
    try:
        toggle = driver.find_element_by_xpath('//*[@id="productDescription"]/div[3]/div[2]')
        toggle.click() 

        ingredient_list.append(driver.find_element_by_xpath('//*[@id="productDescription"]/div[3]/div[2]/div[2]/div/div/div').text) 
    except:
        ingredient_list.append('NA')

# %%
ulta_moisturizer_df = pd.DataFrame(
    {'brand': brand_list[:96],
     'name': product_list[:96],
     'price': price_list[:96],
     'rating': rating_list[:96],
     'ingredients': ingredient_list[:96]
    }) 

pd.set_option('display.max_rows',None)
ulta_moisturizer_df
#ulta_moisturizer_df_keep=ulta_moisturizer_df.copy()
# Out:
#                  brand                                               name  \
# 0   Kiehl's Since 1851      Oil Eliminator 24 Hour Anti Shine Moisturizer
# 1      Elizabeth Arden  Visible Difference Refining Moisture Cream Com...
# 2              Follain                       Age-Defying Best Sellers Duo
# 3         Estée Lauder  Nutritious Super-Pomegranate Radiant Energy Mo...
# 4                Hempz  Travel Size CBD Thirsty Hydrating Facial Moist...
# 5    florence by mills                             Like a Light Skin Tint
# 6           Philosophy  Travel Size Anti-Wrinkle+ Miracle Worker Line ...
# 7                Ahava              Essential Day Moisturizer Combination
# 8                Tarte  Travel Size Shape Tape First Step Prep Moistur...
# 9         Perricone MD  Cold Plasma Plus+ The Intensive Hydrating Complex
# 10               Belli                       Healthy Glow Facial Hydrator
# 11             Garnier  SkinActive Moisture Rescue Refreshing Gel-Crea...
# 12            Pacifica                           Kale Luxe Oil-Free Cream
# 13             EVE LOM                                     Moisture Cream
# 14       Honest Beauty                      Everyday Radiance Moisturizer
# 32                                 Online Only    4.4
# 33                               Price\n$50.00    4.6
# 34                               Price\n$25.00    4.3
# 35                                 Online Only    4.5
# 36                         Only at Ulta Beauty      5
# 37                               Price\n$53.00    4.3
# 38                               Price\n$14.00    4.4
# 39                                 Online Only    4.6
# 40                                 Online Only    4.2
# 41    Sale Price\n$6.29\nOriginal Price\n$8.99      5
# 42                                 Online Only     NA
# 43                         Only at Ulta Beauty    4.8
# 44                               Price\n$18.00     NA
# 45                               Price\n$14.00      4
# 46                                 Online Only    4.5
# 47  Sale Price\n$16.50\nOriginal Price\n$22.00      4
# 48                                 Online Only    4.5
# 49                                 Online Only    4.3
# 50  Sale Price\n$16.10\nOriginal Price\n$23.00      5
# 51  Sale Price\n$16.50\nOriginal Price\n$22.00    4.2
# 52  Sale Price\n$19.99\nOriginal Price\n$24.99    4.5
# 53                                 Online Only    4.4
# 54  Sale Price\n$29.40\nOriginal Price\n$42.00    4.2
# 55                               Price\n$49.00    4.8
# 56                               Price\n$14.00    4.3
# 57                                 Online Only      5
# 58                               Price\n$18.00      4
# 59                                 Online Only    4.5
# 60                               Price\n$30.00    4.6
# 61   Sale Price\n$7.00\nOriginal Price\n$10.00    4.8
# 62   Sale Price\n$8.39\nOriginal Price\n$11.99    4.7
# 63   Sale Price\n$9.19\nOriginal Price\n$11.49    4.2
# 64                               Price\n$48.00      5
# 65                               Price\n$88.00    4.4
# 66           Online Only + Only at Ulta Beauty     NA
# 67                         Only at Ulta Beauty     NA
# 68   Sale Price\n$9.45\nOriginal Price\n$13.50    4.5
# 69  Sale Price\n$33.60\nOriginal Price\n$48.00    4.7
# 70                               Price\n$55.00      5
# 71                               Price\n$65.00    3.6
# 72  Sale Price\n$16.10\nOriginal Price\n$23.00    4.2
# 73                               Price\n$48.00     NA
# 74                               Price\n$22.00     NA
# 75                         Only at Ulta Beauty    4.3
# 76  Sale Price\n$56.25\nOriginal Price\n$75.00     NA
# 77                                 Online Only    3.6
# 78                               Price\n$42.00    4.5
# 79                                 Online Only    4.3
# 80                               Price\n$49.00    3.6
# 81                         Only at Ulta Beauty     NA
# 82                         Only at Ulta Beauty    3.7
# 83  Sale Price\n$14.39\nOriginal Price\n$17.99    3.6
# 84                               Price\n$27.00    4.8
# 85                               Price\n$29.00      3
# 86                               Price\n$14.00    2.5
# 87                                 Online Only    4.2
# 88                                 Online Only    3.9
# 89                                 Online Only    4.6
# 90  Sale Price\n$11.89\nOriginal Price\n$16.99    4.3
# 91                               Price\n$26.00    4.8
# 92                         Only at Ulta Beauty    3.5
# 93                               Price\n$26.00    4.4
# 94                                Price\n$3.49    3.6
# 95                               Price\n$20.50    4.1
#
#                                           ingredients
# 0   Aqua/Water, Glycerin, Alcohol Denat., Dimethic...
# 1   This item is not eligible for coupon discounts...
# 2   Moisturizer: Replenish + Protect: Water/Aqua/E...
# 3   Water\Aqua\Eau, C12-20 Acid PEG-8 Ester, Capry...
# 4                                                  NA
# 5   Aqua (Water, Eau), Glycerin, Glyceryl Stearate...
# 6   Aqua/Water/Eau, Cyclopentasiloxane, Glycerin, ...
# 7   Aqua (Mineral Spring Water), Hexyldecyl Laurat...
# 8   Water/Aqua/Eau, Octyldodecyl Neopentanoate, Ca...
# 9
# 10  Deionized Water, Vitis Vinifera (Grape) Seed O...
# 11  Aqua / Water, Glycerin, Alcohol Denat., Dimeth...
# 12  Aqua (Purified), Aloe Barbadensis Leaf Juice, ...
# 13  Aqua (Water), Caprylic/Capric Triglyceride, C1...
# 14  Water (Aqua), Glycerin, Raphanus Sativus (Radi...
# 15  Water, C9-12 Alkane, Dimethicone, Propanediol,...
# 16  Water (Aqua/Eau), Squalane, Persea Gratissima ...
# 17                                                 NA
# 18  Aqua(Mineral Spring Water), Sodium Hyaluronate...
# 19  Water, Aloe Barbadensis Leaf Juice*, Glyceryl ...
# 20  Water, Glycolic Acid, Ammonium Hydroxide, Glyc...
# 21  Active: Ensulizole (1.7%), Octinoxate (7.5%).\...
# 22  Water (Aqua, Eau), Caprylic/Capric Triglycerid...
# 23  Water, Glycerin, Dimethicone, Rosa Damascena F...
# 24  Water, Dimethicone, Hydrogenated Polyisobutene...
# 25  50 mg CBD\n\nWater, Caprylic/Capric Triglyceri...
# 26  Water, Glycerin, Dicaprylyl Carbonate, Squalen...
# 27  Aqua/Water, Squalane, Cyclohexasiloxane, Glyce...
# 28  Avène Thermal Spring Water, Carthamus tinctori...
# 29  Aqua (Water, Eau), Propylene Glycol, Glycerin,...
# 30  Aqua/Water/Eau, Glycerin, Caprylic/Capric Trig...
# 31  Water*, Lanolin*, Cetearyl Alcohol*, Caprylic/...
# 32  Active Ingredients: Zinc Oxide 11.25%. Titaniu...
# 33  Aqua/Water/Eau, Butylene Glycol, C15-19 Alkane...
# 34  Aqua (Water, Eau), Propylene Glycol, Arachis H...
# 35                                                 NA
# 36  Aqua/Water, Glycerin, Cyclohexasiloxane, Propa...
# 37  Active: Octinoxate 7.5%, Titanium Dioxide 1.5%...
# 38  Water/Aqua/Eau, Cetyl Ethylhexanoate, Glycerin...
# 39  Active Ingredients: Homosalate 15.0%, Avobenzo...
# 40  Water\aqua\eau, glycerin, isododecane, dimethi...
# 41  Active: Allantoin; 0.5%. Inactive: Aloe Barbad...
# 42  Water/Aqua/Eau, Olea Europaea (Olive) Fruit Oi...
# 43  DI Water, Cetyl Ethylhexanoate, Glycerin, Prop...
# 44  Aqua (Water, Eau), Pentylene Glycol, Sodium Ac...
# 45  Water/Aqua/Eau, Citrus Tangerina (Tangerine) F...
# 46  Active: Salicylic Acid 2%. Inactive: Water, Gl...
# 47                                                 NA
# 48  Honey Extract, Aureobasidium Pullulans Ferment...
# 49  Aqua/Water/Eau, Glycerin, Alcohol Denat., Capr...
# 50  Water, Butylene Glycol, Dipropylene Glycol, Si...
# 51  Water (Aqua) (Eau), Cyclopentasiloxane, Capryl...
# 52  Aqua/Water/Eau, Squalane, Cyclohexasiloxane, G...
# 53  Water, Adipic Acid/Neopentyl Glycol Crosspolym...
# 54  Active: Zinc Oxide 13.5%. Inactive: Aloe Barba...
# 55  Water, Butyrospermum Parkii (Shea) Butter, Iso...
# 56  Aqua (Water,Eau), Dimethicone, Niacinamide, Oc...
# 57  Avène Thermal Spring Water, Mineral Oil, Glyce...
# 58  Aqua, Fulvic Acid, Citrus Nobilis (Mandarin Or...
# 59  Bis-Diglyceryl Polyacyladipate-2, Isononyl Iso...
# 60  Water, Butylene Glycol, Squalane,Oryza Sativa ...
# 61  Purified Water, Helianthus Annuus (Sunflower) ...
# 62  Water, Glycerin, Caprylic/Capric Triglyceride,...
# 63  Aqua / Water, Cyclohexasiloxane, Glycerin, But...
# 64  Olea Europaea (Olive) Fruit Oil*, Arnica Monta...
# 65  Aqua/Water/Eau, Glycerin, Caprylic/Capric Trig...
# 66  Water/Aqua/Eau, alcohol, caprylic/capric trigl...
# 67  Face Buff Energizing Scrub:\nAqua (Water/Eau),...
# 68  Aqua (Water), C12-15 Alkyl Benzoate, Glycerin,...
# 69  Aloe Barbadensis Leaf Juice (ORGANIC), Water/A...
# 70  Aqua (Water/Eau), Propanediol, Glycerin, Coco-...
# 71  Butyrospermum Parkii Butter/Shea Butter, Undec...
# 72  Water, Glycerin, Propanediol, Butylene Glycol,...
# 73  Water (Aqua/Eau), Triheptanoin, Biosaccharide ...
# 74  Aqua/Water/Eau, Glycerin, Peg-8, Cocos Nucifer...
# 75  Water/Aqua/Eau, Butylene Glycol, Glycerin, Dim...
# 76  Aqua (Mineral Spring Water), Isodecyl Isononon...
# 77
# 78  Water, Caprylic/Capric Triglyceride, Glycerin,...
# 79  Water, Butylene Glycol, Glycerin, 1,2-Hexanedi...
# 80  Cocos Nucifera (Coconut) Oil*, Glycine Soja (S...
# 81  Water, Cetearyl Alcohol, Borago Officinalis (B...
# 82  Water, Caprylic/capric Triglyceride, Squalane,...
# 83  Aqua/Water, Cyclohexasiloxane, Glycerin, Paraf...
# 84  Water\Aqua\Eau, Dimethicone, Glycerin, Isohexa...
# 85  This item is not eligible for coupon discounts...
# 86  Aqua (Water, Eau), Cetearyl Alcohol, Caprylic/...
# 87  Aqua/Water, Cyclomethicone, Ethylhexyl Methoxy...
# 88  Aloe Barbadensis Leaf Juice*, Purified Water (...
# 89  Water/Aqua/Eau, Butylene Glycol, Olea Europaea...
# 90  Water/Eau, Glycerin, Sclerocarya Birrea Seed O...
# 91  Water/Aqua/Eau, Glycerin, Sodium Polyacrylate,...
# 92  Water, Sorbitan Stearate, C15-19 Alkane, Cetea...
# 93  Aqua/Water/Eau, Cetearyl Isononanoate, Glyceri...
# 94  Water, Glycerin, Hydrogenated Polyisobutene, C...
# 95  Water\Aqua\Eau , Dimethicone , Alcohol Denat. ...

# %%
ulta_moisturizer_df.to_csv('ulta_m6.csv', index = False)

# %%
### Find first product and click to open 
#prod = driver.find_element_by_xpath('//*[@id="xlsImpprod13641053"]/div[2]') 
#prod.click()

# %%
### Get brand
# brand = driver.find_element_by_xpath('//*[@id="js-mobileBody"]/div/div/div/div/div/div/section[1]/div[2]/div/h1/div[1]').text
# print(brand)

# ### Get Product Name 
# name = driver.find_element_by_xpath('//*[@id="js-mobileBody"]/div/div/div/div/div/div/section[1]/div[2]/div/h1/div[2]').text
# print(name) 
 

# ### Get Rating Number
# star = driver.find_element_by_xpath('//*[@id="pr-review-snapshot"]/header/section/div/div[1]/div/div[1]/div').text
# print(star) 

# ### Once on product page, toggle ingredients and get text
# toggle = driver.find_element_by_xpath('//*[@id="productDescription"]/div[3]/div[2]')
# toggle.click() 

# ingredient = driver.find_element_by_xpath('//*[@id="productDescription"]/div[3]/div[2]/div[2]/div/div/div').text
# print(ingredient) 

# ### Get Price 
# price = driver.find_element_by_xpath('//*[@id="js-mobileBody"]/div/div/div/div/div/div/section[1]/div[2]/div/div[3]').text
# print(price)

# %%
# def scrollDown(driver, n_scroll):

#     body = driver.find_element_by_tag_name("body")
#     while n_scroll >= 0:
#         body.send_keys(Keys.PAGE_DOWN)
#         n_scroll -= 1
#     return driver

# %%
##next steps 

#move into data frame 
#scrol through each of the 14 pages
