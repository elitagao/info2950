# %%
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException 
import numpy as np

# %%
### Links for each page of Face Moisturizer 

# driver.get('https://www.ulta.com/skin-care-face-moisturizer?N=27h9')
# driver.get('https://www.ulta.com/skin-care-face-moisturizer?N=27h9&No=96&Nrpp=96')
# driver.get('https://www.ulta.com/skin-care-face-moisturizer?N=27h9&No=192&Nrpp=96')
# driver.get('https://www.ulta.com/skin-care-face-moisturizer?N=27h9&No=288&Nrpp=96') 
# driver.get('https://www.ulta.com/skin-care-face-moisturizer?N=27h9&No=384&Nrpp=96') 
# driver.get(https://www.ulta.com/skin-care-face-moisturizer?N=27h9&No=480&Nrpp=96')

# %%
### Get Chrome Driver Path 
path = r"C:\Users\avach\Downloads\clone\info2950\chromedriver.exe" 
driver = webdriver.Chrome(path) 

### Open Ulta Moisturizer Site
driver.get('https://www.ulta.com/skin-care-face-moisturizer?N=27h9&No=288&Nrpp=96')

# %%
all_prod = driver.find_element_by_xpath('//*[@id="product-category-cont"]')

html_list = all_prod.find_element_by_id("foo16")
all_li = html_list.find_elements_by_tag_name("li")

product_name = []
subpageurl = []


#append links for products to subpageurl list
for li in all_li: 
    first_atag = li.find_element_by_tag_name('a')
    product_links= first_atag.get_attribute('href')
    
#popup link, got rid of it 
    if product_links != 'http://www.ulta.com/ulta/creditcards/landingpage.jsp':
        subpageurl.append(product_links)
        
#get name of hyperlink, not actual link 

#https://sqa.stackexchange.com/questions/37024/how-do-i-get-the-text-of-a-hyperlink-not-the-actual-link-using-selenium-and-py (innerlink source)
        cut_text = first_atag.get_attribute('innerHTML')
        find_alt = cut_text.find('alt="')
        name = cut_text[find_alt+5:]
        find_border = name.find('" border=')
        name2 = name[:find_border]
        if '+' in name2: 
            plus = name2.find('+') 
            name2 = name2[:plus]
            
        product_name.append(name2)

# %%
brand_list = []
product_list = [] 
price_list = [] 
rating_list = []
ingredient_list = []

# %%
##loop to get info on first page 

for link in subpageurl:
    driver.get(link)  

    ## Get brand 
    try:
        brand_list.append(driver.find_element_by_xpath('//*[@id="js-mobileBody"]/div/div/div/div/div/div/section[1]/div[2]/div/h1/div[1]').text)
    except: 
        brand_list.append('NA')
    
    ### Get Product Name 
    try:
        product_list.append(driver.find_element_by_xpath('//*[@id="js-mobileBody"]/div/div/div/div/div/div/section[1]/div[2]/div/h1/div[2]').text)
    except: 
        product_list.append('NA')
     ### Get Price 
    try:
        price_list.append(driver.find_element_by_xpath('//*[@id="js-mobileBody"]/div/div/div/div/div/div/section[1]/div[2]/div/div[3]').text)
    except: 
        price_list.append('NA') 
        
    ### Get Rating Number 
    try: 
        rating_list.append(driver.find_element_by_xpath('//*[@id="pr-review-snapshot"]/header/section/div/div[1]/div/div[1]/div').text)
    except: 
        rating_list.append('NA')

    ### Once on product page, toggle ingredients and get text
    try:
        toggle = driver.find_element_by_xpath('//*[@id="productDescription"]/div[3]/div[2]')
        toggle.click() 

        ingredient_list.append(driver.find_element_by_xpath('//*[@id="productDescription"]/div[3]/div[2]/div[2]/div/div/div').text) 
    except:
        ingredient_list.append('NA')

# %%
ulta_moisturizer_df = pd.DataFrame(
    {'brand': brand_list[:96],
     'name': product_list[:96],
     'price': price_list[:96],
     'rating': rating_list[:96],
     'ingredients': ingredient_list[:96]
    }) 

pd.set_option('display.max_rows',None)
ulta_moisturizer_df
#ulta_moisturizer_df_keep=ulta_moisturizer_df.copy()
# Out:
#                  brand                                               name  \
# 0                 Lano        Everywhere Multi-Cream - Dry Skin Treatment
# 1              Derma E                         Anti-Wrinkle Renewal Cream
# 2                Truly             Flower Child Anti-Aging CBD Face Cream
# 3                Vichy    LiftActiv Peptide-C Anti-Aging Face Moisturizer
# 4             Cetaphil                                 Moisturizing Cream
# 5         Peach Slices       Snail Rescue All-In-One Oil Free Moisturizer
# 6              Clarins                        Hydra-Essentiel Silky Cream
# 7               ELEMIS                Superfood Cica Calm Hydration Juice
# 8     e.l.f. Cosmetics                        Daily Hydration Moisturizer
# 9           StriVectin  Re-Quench Water Cream Hyaluronic + Electrolyte...
# 10            GLAMGLOW      WATERBURST Triple Hyaluronic Glow Moisturizer
# 11                 RoC  Retinol Correxion Deep Wrinkle Daily Moisturiz...
# 12             Derma E                                Hydrating Day Cream
# 13            Clinique  Clinique For Men Broad Spectrum SPF 21 Moistur...
# 14          Neutrogena                   Sensitive Skin Oil-Free Moisture
# 33  Sale Price\n$21.59\nOriginal Price\n$26.99    4.5
# 34                               Price\n$95.00     NA
# 35  Sale Price\n$12.59\nOriginal Price\n$17.99    3.7
# 36                               Price\n$56.00    4.6
# 37                                 Online Only    4.5
# 38                                 Online Only    4.4
# 39                         Only at Ulta Beauty    4.5
# 40  Sale Price\n$15.39\nOriginal Price\n$21.99    4.4
# 41                              Price\n$110.00    4.5
# 42                               Price\n$45.00    4.8
# 43                                 Online Only    4.5
# 44                               Price\n$24.00    4.2
# 45   Sale Price\n$9.79\nOriginal Price\n$13.99    4.2
# 46                                 Online Only    4.4
# 47                               Price\n$55.00      4
# 48                               Price\n$45.00    4.4
# 49                               Price\n$39.50    4.5
# 50                               Price\n$36.00    4.8
# 51                         Only at Ulta Beauty    3.5
# 52                               Price\n$16.00    4.4
# 53   Sale Price\n$8.39\nOriginal Price\n$11.99     NA
# 54                               Price\n$28.00    4.5
# 55                                 Online Only     NA
# 56  Sale Price\n$12.59\nOriginal Price\n$17.99    4.7
# 57                               Price\n$24.00      4
# 58                               Price\n$48.00    3.4
# 59  Sale Price\n$12.59\nOriginal Price\n$17.99    4.7
# 60  Sale Price\n$15.99\nOriginal Price\n$19.99     NA
# 61                                 Online Only    4.8
# 62                               Price\n$30.00    3.8
# 63    Price\n$55.00\nMarket Value\n($69 value)     NA
# 64                               Price\n$32.00    3.8
# 65                               Price\n$38.00    4.3
# 66  Sale Price\n$12.59\nOriginal Price\n$17.99    4.5
# 67                               Price\n$49.00    4.8
# 68                                 Online Only    4.8
# 69  Sale Price\n$23.80\nOriginal Price\n$34.00    4.2
# 70  Sale Price\n$15.39\nOriginal Price\n$21.99    4.2
# 71                               Price\n$39.50    4.1
# 72                               Price\n$14.00      4
# 73                                 Online Only    4.5
# 74                                 Online Only    4.5
# 75                         Only at Ulta Beauty    4.6
# 76                                 Online Only    4.6
# 77                                 Online Only    4.5
# 78  Sale Price\n$10.50\nOriginal Price\n$15.00    4.2
# 79  Sale Price\n$27.29\nOriginal Price\n$38.99    4.4
# 80                               Price\n$39.50    4.4
# 81                               Price\n$60.00    4.5
# 82  Sale Price\n$16.09\nOriginal Price\n$22.99    3.4
# 83                               Price\n$35.00    4.5
# 84                               Price\n$35.00    4.4
# 85                               Price\n$48.00    4.6
# 86                               Price\n$69.00    4.8
# 87                               Price\n$19.50    4.5
# 88                                 Online Only    4.3
# 89                               Price\n$55.00    4.3
# 90                               Price\n$46.00    4.3
# 91                               Price\n$65.00    3.9
# 92                               Price\n$14.00     NA
# 93  Sale Price\n$15.99\nOriginal Price\n$19.99    4.5
# 94  Sale Price\n$34.50\nOriginal Price\n$46.00    4.6
# 95                               Price\n$98.00     NA
#
#                                           ingredients
# 0   Water/Aqua/Eau*, Lanolin*, Cetearyl Alcohol*, ...
# 1   Purified Water, Carthamus Tinctorius (Safflowe...
# 2                                                  NA
# 3   Aqua / Water / Eau, Glycerin, Dimethicone, Iso...
# 4
# 5   Snail Secretion Filtrate, Cetyl Ethylhexanoate...
# 6   Aqua/Water/Eau, Caprylic/Capric Triglyceride, ...
# 7   Aloe Barbadensis Leaf Juice, Aqua/Water/Eau, P...
# 8   Water (Aqua), Butylene Glycol, Hydrogenated Po...
# 9   Aqua/Water/Eau, Dimethicone, Propanediol, Glyc...
# 10  Water\Aqua\Eau, Dimethicone, Glycerin, Dipropy...
# 11  Active: Avobenzone 3%, Homosalate 10%, Octocry...
# 12  Purified Water, Caprylic/Capric Triglyceride (...
# 13  Active: Octinoxate 7.40%, Octisalate 5.00%, Av...
# 14  Water, Glycerin, Ethylhexyl Palmitate, Dimethi...
# 15  Active: Avobenzone 3%, Octinoxate 7.5%, Octisa...
# 16  Aqua/Water/Eau, Glycerin, Propylene Glycol, Ca...
# 17  Water / Aqua / Eau, Mineral Oil / Paraffinum L...
# 18  Water/Aqua/Eau, Dimethicone, Cetyl Ethylhexano...
# 19  This item is not eligible for coupon discounts...
# 20  Water/Aqua/Eau, Glycerin, Dipropylene Glycol, ...
# 21  Aqua (Purified), Aloe Barbadensis Leaf Juice, ...
# 22  This item is not eligible for coupon discounts...
# 23  *Aloe Vera Leaf Juice, *Shea Butter, 12% Zinc ...
# 24  Water/Aqua/Eau, Isocetyl Stearate, Pentaerythr...
# 25  Aqua (Water, Eau), Isopropyl Myristate, Propyl...
# 26  Water, Dimethicone, Glycerin, Dimethicone/Viny...
# 27  Active: Salicylic Acid 2%\nInactive: Water/Aqu...
# 28  Water, Pentaerythrityl Tetraethylhexanoate, Di...
# 29  Water/Aqua/Eau, Butylene Glycol, Caprylic/Capr...
# 30  Water/Aqua/Eau, Glycerin, Sodium Hyaluronate, ...
# 31  Aqua/Water, Squalane, Glycerin, Peg-100 Steara...
# 32  Purified Water, Macadamia Ternifolia Seed Oil,...
# 33  Water, Glycerin, Butylene Glycol, Isononyl Iso...
# 34  Water/Aqua/Eau, Glycerin, Dimethicone, Olive O...
# 35  Water, Dicaprylyl Carbonate, Hydroxyethyl Urea...
# 36  Water\Aqua\Eau, Methyl Trimethicone, Isohexade...
# 37  Water (Aqua/Eau),Helianthus Annuus (Sunflower)...
# 38  Aloe Barbadensis Leaf Juice*, Purified Water (...
# 39  Aqua/Water/Eau, Glycerin, Cetearyl Alcohol, Ne...
# 40  Active: Avobenzone 3%, Homosalate 5%, Octisala...
# 41  Aqua/Water, C12-15 Alkyl Benzoate, Caprylic/Ca...
# 42  *Aloe Vera Leaf Juice, *Mango Seed Butter, *Av...
# 43  Aqua, Helianthus Annuus Seed Oil, Glycerin, Al...
# 44  Active: Avobenzone 3%, Octisalate 5%, Octocryl...
# 45  Aqua (Water), C12-15 Alkyl Benzoate, Glycerin,...
# 46  Water (Aqua/Eau), Caprylic/Capric Triglyceride...
# 47  Active: Avobenzone 2.0%, Homosalate 4.0%, Octi...
# 48  Aqua/Water/Eau, Dicaprylyl Carbonate, Glycerin...
# 49  Clinique iD Active Cartridge Concentrate for I...
# 50  Aqua/Water/Eau, Propanediol, Glycerin, Sodium ...
# 51  Water/Aqua/Eau, Butylene Glycol, Glycerin, Dim...
# 52  Active: Octocrylene 7.6% Zinc Oxide 6%. Inacti...
# 53  Water, Glycerin, Propanediol, Cyclopentasiloxa...
# 54  Active Ingredients: Avobenzone (2.7%), Octinox...
# 55  Water\Aqua\Eau, Pentylene Glycol, Polysorbate ...
# 56  Aqua (Water), Glycerin, Dimethicone, Butylene ...
# 57  Active: Avobenzone 2%, Octinoxate 7.5%, Oxyben...
# 58  Water\Aqua\Eau, Ethylhexyl Salicylate, Glyceri...
# 59  Aqua (Water), Glycerin, Saccharomyces/Xylinum/...
# 60  Active: Avobenzone 3%, Octinoxate 7.5%, Octisa...
# 61  Water/Aqua/Eau, Caprylic/Capric Triglyceride, ...
# 62  Pyrus Malus (Organic Apple Fruit Juice)*,Aloe ...
# 63  Naked Papaya Gentle Enzyme Face Cleanser: Wate...
# 64  Active: Avobenzone 3%, Homosalate 7%, Octisala...
# 65  Active: Avobenzone 2.50%, Homosalate 3.00%, Oc...
# 66  Aqua (Water), Glycerin, Caprylic/Capric Trigly...
# 67  Aqua/Water/Eau, Propylene Glycol, Octyldodecan...
# 68  Gentle Gel Cleanser: Water (Aqua), Sodium Laur...
# 69  Aqua, Dimethicone, Glycerin, Alcohol Denat., N...
# 70  Purified Water, Glycerin (Vegetable Derived), ...
# 71  Clinique iD Active Cartridge Concentrate for F...
# 72  Aqua/Water/Eau, Glycerin, Dimethicone, Propane...
# 73  Aqua/Water/Eau, Rosa Damascena Flower Water, C...
# 74  This item is not eligible for coupon discounts...
# 75  Water (Aqua), Ethylhexyl Palmitate, Glycerin, ...
# 76  Homosalate 8%, Octisalate 4%, Avobenzone 3%, O...
# 77  This item is not eligible for coupon discounts...
# 78  Aqua (Water, Eau), Aloe Barbadensis Leaf Juice...
# 79  Water, Vinyl Dimethicone/Methicone Silsesquiox...
# 80  Base: Water\Aqua\Eau, Propanediol, Glycerin, B...
# 81  Active: Avobenzone 3% Homosalate 2.70% Octisal...
# 82  Water, Glycerin, Sorbitol, Coco-Caprylate/Capr...
# 83  Aqua (Water, Eau), Arachis Hypogaea (Peanut) O...
# 84  Water (Aqua/Eau), Caprylic/Capric Triglyceride...
# 85  Water(Aqua/Eau), Dipropylene Glycol, Glycerin,...
# 86  Active: Avobenzone 3.0%, Homosalate 7.0%, Octi...
# 87  Water (Aqua), Glycerin, Cyclopentasiloxane, Pr...
# 88  Aqua/Water/Eau, Dimethicone, Glycerin, Propane...
# 89  Alcohol, Ammonium Acryloyldimethyltaurate/vp C...
# 90  Aqua/water/eau, C12-15 Alkyl Benzoate, Glucono...
# 91  Water\Aqua\Eau, Butylene Glycol, Caprylic/Capr...
# 92  Aqua/Water/Eau, Cyclopentasiloxane, Stearic Ac...
# 93  Active Ingredients: Avobenzone (1.5%), Homosal...
# 94  Aqua (Mineral Spring Water), Ethylhexyl Palmit...
# 95  This item is not eligible for coupon discounts...

# %%
ulta_moisturizer_df.to_csv('ulta_m4.csv', index = False)

# %%
### Find first product and click to open 
#prod = driver.find_element_by_xpath('//*[@id="xlsImpprod13641053"]/div[2]') 
#prod.click()

# %%
### Get brand
# brand = driver.find_element_by_xpath('//*[@id="js-mobileBody"]/div/div/div/div/div/div/section[1]/div[2]/div/h1/div[1]').text
# print(brand)

# ### Get Product Name 
# name = driver.find_element_by_xpath('//*[@id="js-mobileBody"]/div/div/div/div/div/div/section[1]/div[2]/div/h1/div[2]').text
# print(name) 
 

# ### Get Rating Number
# star = driver.find_element_by_xpath('//*[@id="pr-review-snapshot"]/header/section/div/div[1]/div/div[1]/div').text
# print(star) 

# ### Once on product page, toggle ingredients and get text
# toggle = driver.find_element_by_xpath('//*[@id="productDescription"]/div[3]/div[2]')
# toggle.click() 

# ingredient = driver.find_element_by_xpath('//*[@id="productDescription"]/div[3]/div[2]/div[2]/div/div/div').text
# print(ingredient) 

# ### Get Price 
# price = driver.find_element_by_xpath('//*[@id="js-mobileBody"]/div/div/div/div/div/div/section[1]/div[2]/div/div[3]').text
# print(price)

# %%
# def scrollDown(driver, n_scroll):

#     body = driver.find_element_by_tag_name("body")
#     while n_scroll >= 0:
#         body.send_keys(Keys.PAGE_DOWN)
#         n_scroll -= 1
#     return driver

# %%
##next steps 

#move into data frame 
#scrol through each of the 14 pages
