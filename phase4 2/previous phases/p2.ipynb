# %%
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException 
import numpy as np

# %%
### Links for each page of Face Moisturizer 

# driver.get('https://www.ulta.com/skin-care-face-moisturizer?N=27h9')
# driver.get('https://www.ulta.com/skin-care-face-moisturizer?N=27h9&No=96&Nrpp=96')
# driver.get('https://www.ulta.com/skin-care-face-moisturizer?N=27h9&No=192&Nrpp=96')
# driver.get('https://www.ulta.com/skin-care-face-moisturizer?N=27h9&No=288&Nrpp=96') 
# driver.get('https://www.ulta.com/skin-care-face-moisturizer?N=27h9&No=384&Nrpp=96') 
# driver.get(https://www.ulta.com/skin-care-face-moisturizer?N=27h9&No=480&Nrpp=96')

# %%
### Get Chrome Driver Path 
path = r"C:\Users\avach\Downloads\clone\info2950\chromedriver.exe" 
driver = webdriver.Chrome(path) 

### Open Ulta Moisturizer Site
driver.get('https://www.ulta.com/skin-care-face-moisturizer?N=27h9&No=96&Nrpp=96')

# %%
all_prod = driver.find_element_by_xpath('//*[@id="product-category-cont"]')

html_list = all_prod.find_element_by_id("foo16")
all_li = html_list.find_elements_by_tag_name("li")

product_name = []
subpageurl = []


#append links for products to subpageurl list
for li in all_li: 
    first_atag = li.find_element_by_tag_name('a')
    product_links= first_atag.get_attribute('href')
    
#popup link, got rid of it 
    if product_links != 'http://www.ulta.com/ulta/creditcards/landingpage.jsp':
        subpageurl.append(product_links)
        
#get name of hyperlink, not actual link 

#https://sqa.stackexchange.com/questions/37024/how-do-i-get-the-text-of-a-hyperlink-not-the-actual-link-using-selenium-and-py (innerlink source)
        cut_text = first_atag.get_attribute('innerHTML')
        find_alt = cut_text.find('alt="')
        name = cut_text[find_alt+5:]
        find_border = name.find('" border=')
        name2 = name[:find_border]
        if '+' in name2: 
            plus = name2.find('+') 
            name2 = name2[:plus]
            
        product_name.append(name2)

# %%
brand_list = []
product_list = [] 
price_list = [] 
rating_list = []
ingredient_list = []

# %%
##loop to get info on first page 

for link in subpageurl:
    driver.get(link)  

    ## Get brand 
    try:
        brand_list.append(driver.find_element_by_xpath('//*[@id="js-mobileBody"]/div/div/div/div/div/div/section[1]/div[2]/div/h1/div[1]').text)
    except: 
        brand_list.append('NA')
    
    ### Get Product Name 
    try:
        product_list.append(driver.find_element_by_xpath('//*[@id="js-mobileBody"]/div/div/div/div/div/div/section[1]/div[2]/div/h1/div[2]').text)
    except: 
        product_list.append('NA')
     ### Get Price 
    try:
        price_list.append(driver.find_element_by_xpath('//*[@id="js-mobileBody"]/div/div/div/div/div/div/section[1]/div[2]/div/div[3]').text) 
    except:
        price_list.append('NA') 
        
    ### Get Rating Number 
    try: 
        rating_list.append(driver.find_element_by_xpath('//*[@id="pr-review-snapshot"]/header/section/div/div[1]/div/div[1]/div').text)
    except: 
        rating_list.append('NA')

    ### Once on product page, toggle ingredients and get text
    try:
        toggle = driver.find_element_by_xpath('//*[@id="productDescription"]/div[3]/div[2]')
        toggle.click() 

        ingredient_list.append(driver.find_element_by_xpath('//*[@id="productDescription"]/div[3]/div[2]/div[2]/div/div/div').text) 
    except:
        ingredient_list.append('NA')

# %%
ulta_moisturizer_df = pd.DataFrame(
    {'brand': brand_list[:96],
     'name': product_list[:96],
     'price': price_list[:96],
     'rating': rating_list[:96],
     'ingredients': ingredient_list[:96]
    }) 

pd.set_option('display.max_rows',None)
ulta_moisturizer_df
#ulta_moisturizer_df_keep=ulta_moisturizer_df.copy()
# Out:
#                   brand                                               name  \
# 0              Clinique  Clinique iD Dramatically Different For Lines &...
# 1               Lancôme  Bienfait Multi-Vital SPF 30 Day Cream Moisturizer
# 2            Neutrogena  Hydro Boost City Shield Water Gel Sunscreen SP...
# 3                 Murad                    Hydro-Dynamic Ultimate Moisture
# 4                 Murad                             Intense Recovery Cream
# 5          SUNDAY RILEY                    Ice Ceramide Moisturizing Cream
# 6                 Curél                    Intensive Moisture Facial Cream
# 7            Philosophy                     Purity Made Simple Moisturizer
# 8        La Roche-Posay  Anthelios 50 Daily Face Primer with Sunscreen ...
# 9              GLAMGLOW  GLOWSTARTER Mega Illuminating Hyaluronic Acid ...
# 10         It Cosmetics  Confidence in a Cream Rosy Tone Skin Brighteni...
# 11             Clinique              Clinique For Men Anti-Age Moisturizer
# 12               ELEMIS                   Pro-Collagen Marine Cream SPF 30
# 13        Honest Beauty                                     Hydrogel Cream
# 14              Clarins  Extra-Firming Wrinkle Control Firming Day Crea...
# 15         Estée Lauder  Resilience Multi-Effect Tri-Peptide Face and N...
# 16            Exuviance                      Age Reverse Day Repair SPF 30
# 17                 Olay   Total Effects Anti-Aging Moisturizer With SPF 30
# 18                 Olay    Regenerist Fragrance-Free Micro-Sculpting Cream
# 19           StriVectin                  Tightening & Sculpting Face Cream
# 20               CeraVe                     Skin Renewing Day Cream SPF 30
# 21                 Tula           Super Soothe Calming Moisturizing Lotion
# 22                 Tula                  Dew Your Thing Oil Free Gel Cream
# 23     e.l.f. Cosmetics                           SuperHydrate Moisturizer
# 24          Josie Maran                      Whipped Argan Oil Face Butter
# 25     First Aid Beauty  Hello FAB Coconut Skin Smoothie Priming Moistu...
# 26             Clinique                     Even Better Moisturizer SPF 20
# 27               Weleda                Skin Food Original Ultra-Rich Cream
# 28                  MAC                                       Strobe Cream
# 29           KYLIE SKIN                                   Face Moisturizer
# 30             Clinique  Clinique iD Dramatically Different For Pores &...
# 31             Clinique            Clinique iD Dramatically Different Base
# 32                  RoC        Retinol Correxion Max Daily Hydration Crème
# 33          Dermalogica  Travel Size Dynamic Skin Recovery Broad Spectr...
# 34      Kate Somerville  Wrinkle Warrior 2-in-1 Plumping Moisturizer + ...
# 35    Peter Thomas Roth                Water Drench Hyaluronic Cloud Serum
# 36    Peter Thomas Roth      Potent-C Vitamin C Bright & Plump Moisturizer
# 37                Murad  Anti-Aging Moisturizer Broad Spectrum SPF 30 |...
# 38          Dermalogica                              Prisma Protect SPF 30
# 39    Peter Thomas Roth  Water Drench Broad Spectrum SPF 45 Hyaluronic ...
# 40                 Olay            Complete UV365 Daily Moisturizer SPF 30
# 41             Pacifica                     Glow Baby VitaGlow Face Lotion
# 42         PEACH & LILY                   Glass Skin Water Gel Moisturizer
# 43             Clinique  Moisture Surge Hydrating Supercharged Concentrate
# 44       Josh Rosebrook                              Hydrating Accelerator
# 45         Juice Beauty                   GREEN APPLE Age Defy Moisturizer
# 46               CeraVe                     Travel Size Moisturizing Cream
# 47          Josie Maran             Argan Daily Moisturizer Mineral SPF 47
# 48         Estée Lauder  Revitalizing Supreme+ Global Anti-Aging Cell P...
# 49             Shiseido        Benefiance Wrinkle Smoothing Cream Enriched
# 50         PEACH & LILY                 Lazy Day's All-In-One Moisture Pad
# 51         Estée Lauder  DayWear Matte Oil-Control Anti-Oxidant Moistur...
# 52     e.l.f. Cosmetics                         Holy Hydration! Face Cream
# 53    Peter Thomas Roth                Day & Night Moisture Must-Haves Kit
# 54              L'Oréal  Revitalift Triple Power Anti-Aging Face Moistu...
# 55           StriVectin         Wrinkle Recode Moisture Rich Barrier Cream
# 56          Josie Maran      Pure Argan Milk Intensive Hydrating Treatment
# 57    Peter Thomas Roth                         FIRMx Collagen Moisturizer
# 58         SUNDAY RILEY               Tidal Brightening Enzyme Water Cream
# 59     First Aid Beauty               Ultra Repair Oil-Control Moisturizer
# 60        Urban Skin Rx            Complexion Protection Moisturizer SPF30
# 61             Pacifica              Dreamy Youth Day And Night Face Cream
# 62          Dermalogica    Clear Start Clearing Defense Moisturizer SPF 30
# 63                  RoC            Multi Correxion Revive + Glow Gel Cream
# 64                 Olay  Regenerist Ultra Rich Fragrance-Free Hydrating...
# 65             Shiseido  Bio-Performance Advanced Super Revitalizing Cream
# 66              Derma E                     Vitamin C Renewing Moisturizer
# 67             Proactiv                              Green Tea Moisturizer
# 68         bareMinerals             SMOOTHNESS Bare Haven Soft Moisturizer
# 69     First Aid Beauty                           5 in 1 Face Cream SPF 30
# 70              Origins    Original Skin Matte Moisturizer With Willowherb
# 71                Avène            Cicalfate+ Restorative Protective Cream
# 72                Murad                               Clarifying Water Gel
# 73                Bliss  Bright Idea Vitamin C + Tri-Peptide Collagen P...
# 74                 Olay            Regenerist Whip Face Moisturizer SPF 25
# 75             Clinique           Clinique iD Active Cartridge Concentrate
# 76         bareMinerals                   Ageless Phyto-Retinol Face Cream
# 77           Philosophy                               The Wrinkle Takeaway
# 78              Derma E             Skin De-Stress Calming CBD Moisturizer
# 79      Kate Somerville                       Goat Milk Moisturizing Cream
# 80         Juice Beauty                      STEM CELLULAR Day & Night Duo
# 81         Skyn Iceland                  The ANTIDOTE Cooling Daily Lotion
# 82              Clarins                      Multi-Active Day Cream SPF 20
# 83               CeraVe                     Itch Relief Moisturizing Cream
# 84             Clinique  Superdefense City Block SPF 50+ Daily Energy +...
# 85   Kiehl's Since 1851                          Ultra Facial Cream SPF 30
# 86              Origins  Dr. Andrew Weil for Origins Mega-Mushroom Reli...
# 87                  PÜR                                 4-In-1 Cloud Cream
# 88             Cetaphil        DermaControl Oil Control Moisturizer SPF 30
# 89           bioClarity  SunFilter SPF 30 Mineral Face Sunscreen + 12 H...
# 90              Lancôme  Rénergie Lift Multi-Action Ultra Sunscreen Bro...
# 91              Lancôme  UV Expert Aquagel Defense Sunscreen, Primer & ...
# 92               CeraVe                    Itch Relief Moisturizing Lotion
# 93          LOLI Beauty    Date Nut Brûlée Organic Nourishing Miracle Balm
# 94  Too Cool For School                                   Egg Mellow Cream
# 95    Meaningful Beauty  Anti-Aging Day Crème with Environmental Protec...
#
#                                          price rating  \
# 0                                Price\n$39.50    3.6
# 1                                Price\n$56.00    4.7
# 2   Sale Price\n$23.19\nOriginal Price\n$28.99     NA
# 3                                Price\n$75.00    4.5
# 4                          Only at Ulta Beauty    4.7
# 5                                Price\n$65.00    4.3
# 6   Sale Price\n$21.00\nOriginal Price\n$30.00    4.7
# 7                                Price\n$28.00    4.5
# 8   Sale Price\n$31.99\nOriginal Price\n$39.99    4.3
# 9                                Price\n$50.00      4
# 10                               Price\n$49.00    4.5
# 11                               Price\n$41.00    4.5
# 12                              Price\n$128.00    4.8
# 13                                 Online Only     NA
# 14                               Price\n$88.00    4.3
# 15                                 Online Only     NA
# 16                               Price\n$75.00     NA
# 17  Sale Price\n$17.49\nOriginal Price\n$24.99     NA
# 18  Sale Price\n$20.29\nOriginal Price\n$28.99     NA
# 19                               Price\n$95.00     NA
# 20  Sale Price\n$19.99\nOriginal Price\n$24.99    3.3
# 21                               Price\n$46.00    4.4
# 22                               Price\n$48.00    4.7
# 23   Sale Price\n$8.40\nOriginal Price\n$12.00    4.1
# 24                               Price\n$42.00    4.7
# 25                               Price\n$30.00    4.3
# 26                               Price\n$53.00    4.4
# 27                                 Online Only    4.6
# 28                               Price\n$35.00    4.3
# 29                               Price\n$24.00    4.3
# 30                               Price\n$39.50    4.3
# 31                               Price\n$25.00    4.3
# 32  Sale Price\n$19.24\nOriginal Price\n$27.49    4.6
# 33                               Price\n$22.00    4.6
# 34                                 Online Only    4.4
# 35                               Price\n$65.00    4.3
# 36                               Price\n$68.00    3.4
# 37                               Price\n$50.00     NA
# 38                               Price\n$65.00    4.6
# 39                               Price\n$52.00    4.8
# 40   Sale Price\n$9.79\nOriginal Price\n$13.99    4.5
# 41  Sale Price\n$10.50\nOriginal Price\n$15.00     NA
# 42                         Only at Ulta Beauty      4
# 43                               Price\n$41.00     NA
# 44                               Price\n$35.00    4.9
# 45                               Price\n$50.00    4.5
# 46                                Price\n$5.49    4.6
# 47                               Price\n$34.00    3.6
# 48                               Price\n$88.00     NA
# 49                               Price\n$70.00     NA
# 50                         Only at Ulta Beauty    4.6
# 51                               Price\n$55.00     NA
# 52   Sale Price\n$8.40\nOriginal Price\n$12.00     NA
# 53    Price\n$28.00\nMarket Value\n($69 value)     NA
# 54  Sale Price\n$19.99\nOriginal Price\n$24.99     NA
# 55                              Price\n$119.00     NA
# 56                               Price\n$56.00     NA
# 57                               Price\n$85.00    4.3
# 58                               Price\n$65.00    3.5
# 59                               Price\n$32.00    4.4
# 60  Sale Price\n$13.99\nOriginal Price\n$19.99    4.3
# 61  Sale Price\n$11.20\nOriginal Price\n$16.00     NA
# 62                               Price\n$28.00    4.2
# 63  Sale Price\n$20.99\nOriginal Price\n$29.99    4.7
# 64  Sale Price\n$27.29\nOriginal Price\n$38.99    4.6
# 65                               Price\n$85.00    4.8
# 66  Sale Price\n$13.99\nOriginal Price\n$19.99     NA
# 67                               Price\n$40.00    4.4
# 68                               Price\n$35.00    3.7
# 69                               Price\n$40.00     NA
# 70                               Price\n$36.00    4.5
# 71                                 Online Only    3.4
# 72                               Price\n$44.00    4.6
# 73  Sale Price\n$18.00\nOriginal Price\n$24.00    4.5
# 74  Sale Price\n$27.29\nOriginal Price\n$38.99     NA
# 75                               Price\n$14.50      4
# 76                               Price\n$62.00    4.6
# 77    Price\n$47.00\nMarket Value\n($73 value)     NA
# 78  Sale Price\n$15.05\nOriginal Price\n$21.50    4.6
# 79                                 Online Only    4.5
# 80                                 Online Only    4.8
# 81                               Price\n$48.00    4.5
# 82                               Price\n$55.00    4.3
# 83                               Price\n$24.99    4.6
# 84                               Price\n$29.50     NA
# 85                               Price\n$32.00    3.8
# 86                               Price\n$34.00     NA
# 87                               Price\n$38.00    4.3
# 88  Sale Price\n$13.29\nOriginal Price\n$18.99    3.6
# 89           Online Only + Only at Ulta Beauty    4.6
# 90                              Price\n$130.00    4.5
# 91                               Price\n$40.00    4.2
# 92                               Price\n$18.99    4.6
# 93                               Price\n$48.00    4.8
# 94  Sale Price\n$25.20\nOriginal Price\n$36.00    4.4
# 95                               Price\n$65.00      5
#
#                                           ingredients
# 0
# 1   Water, Dimethicone, Glycerin, Alcohol Denat., ...
# 2
# 3   Water (Aqua), C12-15 Alkyl Benzoate, Caprylic/...
# 4   Water/Aqua/Eau, Ethylhexyl Palmitate, Betaine,...
# 5   Extract Blend [Water/Eau/Aqua, Chondrus Crispu...
# 6   Water/Aqua, Glycerin, Cetyl-PG Hydroxyethyl Pa...
# 7   Aqua/Water/Eau, Cyclopentasiloxane, Bis-PEG-18...
# 8   Active: Avobenzone 3% (Sunscreen), Homosalate ...
# 9   Water\Aqua\Eau, Dimethicone, Butylene Glycol, ...
# 10  Aqua / Water / Eau, Squalane, Cyclohexasiloxan...
# 11  Water\Aqua\Eau , Squalane , Glycerin , Isostea...
# 12  Water, Glycerin, Caprylic/Capric Triglyceride,...
# 13  Water (aqua), Squalane, Glycerin, Polyglyceryl...
# 14  Active: Avobenzone 3%, Homosalate 9%, Octocryl...
# 15  Active: Avobenzone 3.0%, Octisalate 4.5%, Octo...
# 16  Active: Avobenzone 3% Octinoxate 7.5% Octisala...
# 17  Water, Glycerin, Polymethylsilsesquioxane, Nia...
# 18  Water, Glycerin, Isohexadecane, Niacinamide, I...
# 19  Aqua (Water, Eau), Stearic Acid, Neopentyl Gly...
# 20  Active: Octinoxate 7.5 %, Zinc Oxide 10.5 %. I...
# 21  Aqua/Water/Eau, Glycerin, C13-15 Alkane, Propa...
# 22  Aqua/Water/Eau, Pro-panediol, Cyclopentasiloxa...
# 23  Water (Aqua), Butylene Glycol, Glycerin, Dimet...
# 24  Aqua (Water)**, Argania Spinosa (Argan) Kernel...
# 25  Cocos Nucifera (Coconut) Fruit Juice, Glucose,...
# 26  Active: Octisalate 5.00%, Avobenzone 3.00%, Oc...
# 27  Aqua, Helianthus, Annuus Seed Oil, Lanolin, Pr...
# 28  Water / Aqua / Eau, Dimethicone, Butylene Glyc...
# 29  Water/Aqua/Eau, Isopropyl Palmitate, Propanedi...
# 30  Clinique iD Active Cartridge Concentrate for P...
# 31  Water\Aqua\Eau, Propanediol, Glycerin, Butylen...
# 32  Water, Pentaerythrityl Tetraethylhexanoate, Gl...
# 33  Active ingredients: Avobenzone (3.0%), Octinox...
# 34  Water/Aqua/Eau, Dimethicone, Propanediol, Dime...
# 35  Water/Aqua/Eau, Saccharide Isomerate, Sodium H...
# 36  Water/Aqua/Eau, Propanediol, Tetrahexyldecyl A...
# 37  Active Ingredients: Avobenzone 3.0%, Homosalat...
# 38  Water, Homosalate, Octocrylene, Silica, Butyle...
# 39  Active: Avobenzone 3%, Homosalate 5%, Octisala...
# 40  Active: Homosalate 8.0%, Avobenzone 3.0%, Octo...
# 41  Aqua, Aloe Barbadensis Leaf Juice, Caprylic/Ca...
# 42  Water (Aqua), Glycerin, Propanediol, 1,2-Hexan...
# 43  Water\Aqua\Eau, Glycerin, Butylene Glycol, Phe...
# 44  *Aloe Vera Leaf Juice, *Jojoba Oil, +Marula Oi...
# 45  Aloe Barbadensis (Organic Aloe Juice)*, Pyrus ...
# 46  Purified Water, Glycerin, Cetareth-20 and Cete...
# 47  Active: Titanium Dioxide 5.1%, Zinc Oxide 6.4%...
# 48  Water\Aqua\Eau, Butyloctyl Salicylate, Glyceri...
# 49  Water(Aqua/Eau), Cetyl Ethylhexanoate, Glyceri...
# 50  Water, Butylene Glycol, Glycerin, 1,2-Hexanedi...
# 51  Water / Aqua / Eau, Isododecane, Butylene Glyc...
# 52  Water (Aqua), Isohexadecane, Stearyl Heptanoat...
# 53  Water Drench Hyaluronic Cloud Cream Hydrating ...
# 54  Revitalift Triple Power Day Cream  Formula  91...
# 55  Water/Aqua/Eau, Caprylic/Capric/Myristic/Stear...
# 56  Water (Aqua)**, Argania Spinosa (Argan) Kernel...
# 57  Vegetable Collagen, Water/Aqua/Eau, Dimethicon...
# 58  Water/Eau/ Aqua, Propanediol, Glycerin, Capryl...
# 59  Water/Aqua/Eau, Dimethicone, Propanediol, Buty...
# 60  Active: Benzophenone-3 6% Butyl Methoxydibenzo...
# 61  Purified Water, Helianthus Annuus (Sunflower) ...
# 62  Water/Aqua/Eau, Homosalate, Octocrylene, Ethyl...
# 63  Water, Dicaprylyl Carbonate, Trimethylolpropan...
# 64  Water, Niacinamide, Glycerin, Hexyldecanol, Di...
# 65  Water (Aqua), Glycerin, Butylene Glycol, Isodo...
# 66  Purified Water, Caprylic/Capric Triglyceride (...
# 67  Water (Aqua), Glycerin, Butylene Glycol, Dimet...
# 68  Water (Aqua/Eau ), Tricaprylin, Butylene Glyco...
# 69  Active: Octinoxate 5.6%, Octocrylene 7.5%, Zin...
# 70  Water\Aqua\Eau, Dimethicone, Alcohol Denat., G...
# 71  Water / Eau (aqua), Caprylic/capric Triglyceri...
# 72  Water/Aqua/Eau, Hammelis Virginiana (Witch Haz...
# 73  Water (Aqua) (Eau), Glycerin, Caprylic/Capric ...
# 74  Active: Avobenzone 3.0%, Homosalate 8.0%, Octi...
# 75  Water\Aqua\Eau, Propanediol, Butylene Glycol, ...
# 76  Water (Aqua/Eau), Squalane, Butylene Glycol, O...
# 77  Purity Made Simple One-Step Facial Cleanser:\n...
# 78  Purified Water, Aloe Barbadensis Leaf Juice, C...
# 79  Water/Aqua/Eau, Ethylhexyl Palmitate, Myristyl...
# 80  STEM CELLULAR Anti-Wrinkle Moisturizer:\nPyrus...
# 81  Water/Aqua/Eau, Glycerin, Butylene Glycol, Sod...
# 82  Active (Sunscreen): Avobenzone 3%, Homosalate ...
# 83  Aqua/Water/Eau, Glycerin, Petrolatum, Cetyl Al...
# 84  Octinoxate 5.0%, Titanium Dioxide 3.2%, Zinc O...
# 85  Active: Avobenzone 3%, Homosalate 5%, Octisala...
# 86  Water\Aqua\Eau, Squalane, Simmondsia Chinensis...
# 87  Aqua, Dimethicone, Propylene Glycol, Glycerin,...
# 88  Active: Avobenzone 3%, Octisalate (5%), Octocr...
# 89  Active Ingredients: Zinc Oxide: 12%. Inactive ...
# 90  Water, Glycerin, Dimethicone, Silica, Peg-100 ...
# 91  Active: Avobenzone 3%, Homosalate 10.7%, Octis...
# 92  Aqua / Water / Eau, Isopropyl Myristate, Peg-1...
# 93  Balanites Aegyptiaca (Desert Date) Kernel Oil*...
# 94  Water, Isohexadecane, Glycerin, Egg Yolk Extra...
# 95  Active: Avobenzone - 3.0%, Homosalate - 10.0%,...

# %%
ulta_moisturizer_df.to_csv('ulta_m2.csv', index = False)

# %%
### Find first product and click to open 
#prod = driver.find_element_by_xpath('//*[@id="xlsImpprod13641053"]/div[2]') 
#prod.click()

# %%
### Get brand
# brand = driver.find_element_by_xpath('//*[@id="js-mobileBody"]/div/div/div/div/div/div/section[1]/div[2]/div/h1/div[1]').text
# print(brand)

# ### Get Product Name 
# name = driver.find_element_by_xpath('//*[@id="js-mobileBody"]/div/div/div/div/div/div/section[1]/div[2]/div/h1/div[2]').text
# print(name) 
 

# ### Get Rating Number
# star = driver.find_element_by_xpath('//*[@id="pr-review-snapshot"]/header/section/div/div[1]/div/div[1]/div').text
# print(star) 

# ### Once on product page, toggle ingredients and get text
# toggle = driver.find_element_by_xpath('//*[@id="productDescription"]/div[3]/div[2]')
# toggle.click() 

# ingredient = driver.find_element_by_xpath('//*[@id="productDescription"]/div[3]/div[2]/div[2]/div/div/div').text
# print(ingredient) 

# ### Get Price 
# price = driver.find_element_by_xpath('//*[@id="js-mobileBody"]/div/div/div/div/div/div/section[1]/div[2]/div/div[3]').text
# print(price)

# %%
# def scrollDown(driver, n_scroll):

#     body = driver.find_element_by_tag_name("body")
#     while n_scroll >= 0:
#         body.send_keys(Keys.PAGE_DOWN)
#         n_scroll -= 1
#     return driver

# %%
##next steps 

#move into data frame 
#scrol through each of the 14 pages
