# %%
# This notebook combines all 7 pages scraped from ulta 
# Now use combined_ulta.csv for all future purposes

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import re 
from scipy import stats

import seaborn as sns

# %%
page1= pd.read_csv('ulta_m1.csv')
page1.head()
# Out:
#                brand                                               name  \
# 0       It Cosmetics       Confidence In A Cream Anti-Aging Moisturizer
# 1           Clinique        Dramatically Different Moisturizing Lotion+
# 2  Peter Thomas Roth  Water Drench Hyaluronic Cloud Cream Hydrating ...
# 3             ELEMIS                          Pro-Collagen Marine Cream
# 4         StriVectin  SD Advanced Intensive Concentrate for Wrinkles...
#
#             price  rating                                        ingredients
# 0   Price\n$49.00     4.5                                                NaN
# 1   Price\n$29.50     4.3                                                NaN
# 2   Price\n$52.00     4.4  Water/Aqua/Eau, Glycerin, Dipropylene Glycol, ...
# 3  Price\n$128.00     4.5  Aqua/Water/Eau, Glycerin, Caprylic/Capric Trig...
# 4  Price\n$139.00     4.5  Aqua (Water, Eau), Glycerin, Pentaerythrityl T...

# %%
page2= pd.read_csv('ulta_m2.csv')
page2.head()
# Out:
#         brand                                               name  \
# 0    Clinique  Clinique iD Dramatically Different For Lines &...
# 1     Lancôme  Bienfait Multi-Vital SPF 30 Day Cream Moisturizer
# 2  Neutrogena  Hydro Boost City Shield Water Gel Sunscreen SP...
# 3       Murad                    Hydro-Dynamic Ultimate Moisture
# 4       Murad                             Intense Recovery Cream
#
#                                         price  rating  \
# 0                               Price\n$39.50     3.6
# 1                               Price\n$56.00     4.7
# 2  Sale Price\n$23.19\nOriginal Price\n$28.99     NaN
# 3                               Price\n$75.00     4.5
# 4                         Only at Ulta Beauty     4.7
#
#                                          ingredients
# 0                                                NaN
# 1  Water, Dimethicone, Glycerin, Alcohol Denat., ...
# 2                                                NaN
# ...

# %%
page3= pd.read_csv('ulta_m3.csv')
page3.head()
# Out:
#              brand                                               name  \
# 0  Elizabeth Arden                   Eight Hour Cream Skin Protectant
# 1            Murad              City Skin Overnight Detox Moisturizer
# 2    Kopari Beauty                  Coconut Water Moisture Face Cream
# 3       Philosophy  Clear Days Ahead Oil-Free Salicylic Acid Acne ...
# 4           Aveeno        Positively Radiant Daily Moisturizer SPF 30
#
#                                         price  rating  \
# 0                                 Online Only     4.1
# 1                               Price\n$74.00     4.7
# 2                               Price\n$25.00     4.7
# 3                         Only at Ulta Beauty     4.4
# 4  Sale Price\n$15.99\nOriginal Price\n$19.99     4.4
#
#                                          ingredients
# 0  Active: Petrolatum 56.8%. Other: Lanolin, Mine...
# 1  Water (Aqua), Glycerin, Shea Butter Ethyl Este...
# 2  Water/Aqua/EAU, Caprylic/Capric Triglyceride, ...
# ...

# %%
pd.set_option('display.max_rows',None)
ulta_df= pd.concat([page1, page2], ignore_index=True)

# %%
ulta_df3= pd.concat([ulta_df, page3], ignore_index=True)
len(ulta_df3)
# Out:
# 288

# %%
page4= pd.read_csv('ulta_m4.csv')
page4.head()
# Out:
#       brand                                             name  \
# 0      Lano      Everywhere Multi-Cream - Dry Skin Treatment
# 1   Derma E                       Anti-Wrinkle Renewal Cream
# 2     Truly           Flower Child Anti-Aging CBD Face Cream
# 3     Vichy  LiftActiv Peptide-C Anti-Aging Face Moisturizer
# 4  Cetaphil                               Moisturizing Cream
#
#                                         price  rating  \
# 0  Sale Price\n$12.71\nOriginal Price\n$16.95     4.5
# 1  Sale Price\n$10.46\nOriginal Price\n$14.95     4.6
# 2                         Only at Ulta Beauty     4.0
# 3                                 Online Only     3.9
# 4  Sale Price\n$12.59\nOriginal Price\n$17.99     4.7
#
#                                          ingredients
# 0  Water/Aqua/Eau*, Lanolin*, Cetearyl Alcohol*, ...
# 1  Purified Water, Carthamus Tinctorius (Safflowe...
# 2                                                NaN
# 3  Aqua / Water / Eau, Glycerin, Dimethicone, Iso...
# ...

# %%
ulta_df4= pd.concat([ulta_df3, page4], ignore_index=True)
len(ulta_df4)
# Out:
# 384

# %%
page5= pd.read_csv('ulta_m5.csv')
page5.head()
# Out:
#              brand                                               name  \
# 0          Garnier  Green Labs Canna-B Pore Perfecting Serum Cream...
# 1   Formula 10.0.6             Picture Perfect Day Moisturizer SPF 15
# 2  Elizabeth Arden    Eight Hour Cream Skin Protectant Fragrance Free
# 3           Aveeno             Ultra-Calming Daily Moisturizer SPF 30
# 4         Botanics                   Simply Calm Hydrating Face Cream
#
#                                         price  rating  \
# 0  Sale Price\n$15.39\nOriginal Price\n$21.99     4.5
# 1    Sale Price\n$5.24\nOriginal Price\n$7.49     3.8
# 2                                 Online Only     4.5
# 3  Sale Price\n$15.99\nOriginal Price\n$19.99     4.2
# 4  Sale Price\n$12.59\nOriginal Price\n$17.99     4.5
#
#                                          ingredients
# 0  Active: Avobenzone 3%, Homosalate 5%, Octisala...
# 1  Active: Avobenzone 2.0%, Octocrylene 6.0%, Sal...
# 2  Petrolatum, Lanolin, Mineral Oil / Paraffinum ...
# ...

# %%
ulta_df5= pd.concat([ulta_df4, page5], ignore_index=True)
len(ulta_df5)
# Out:
# 480

# %%
page6= pd.read_csv('ulta_m6.csv')
page6.head()
# Out:
#                 brand                                               name  \
# 0  Kiehl's Since 1851      Oil Eliminator 24 Hour Anti Shine Moisturizer
# 1     Elizabeth Arden  Visible Difference Refining Moisture Cream Com...
# 2             Follain                       Age-Defying Best Sellers Duo
# 3        Estée Lauder  Nutritious Super-Pomegranate Radiant Energy Mo...
# 4               Hempz  Travel Size CBD Thirsty Hydrating Facial Moist...
#
#                                        price  rating  \
# 0                              Price\n$28.00     4.0
# 1                                Online Only     4.3
# 2                                Online Only     NaN
# 3                                Online Only     4.5
# 4  Sale Price\n$8.40\nOriginal Price\n$12.00     4.5
#
#                                          ingredients
# 0  Aqua/Water, Glycerin, Alcohol Denat., Dimethic...
# 1  This item is not eligible for coupon discounts...
# ...

# %%
ulta_df6= pd.concat([ulta_df5, page6], ignore_index=True)
len(ulta_df6)
# Out:
# 576

# %%
page7= pd.read_csv('ulta_m7.csv')
page7.head()
# Out:
#           brand                                            name  \
# 0      Pacifica           Sea & C Bright Luminizing Face Lotion
# 1    L'Occitane            Immortelle Divine Light Cream SPF 20
# 2    StriVectin  Full Screen SPF 30 100% Mineral Vanishing Tint
# 3  YourGoodSkin                   SPF 30 Anti-Oxidant Day Cream
# 4      SkinKick           Naturally Smart Blemish Relief Lotion
#
#                                         price  rating  \
# 0   Sale Price\n$9.80\nOriginal Price\n$14.00     3.8
# 1                                 Online Only     3.7
# 2                               Price\n$39.00     4.4
# 3   Sale Price\n$9.09\nOriginal Price\n$12.99     4.0
# 4  Sale Price\n$18.20\nOriginal Price\n$26.00     5.0
#
#                                          ingredients
# 0  Water, Cetearyl Alcohol, Prunus Amygdalus Dulc...
# 1  Active: Avobenzone 3%, Homosalate 9%, Octinoxa...
# 2  Active: Zinc Oxide 16%\nInactive: Water/Aqua/E...
# ...

# %%
ulta_df7= pd.concat([ulta_df6, page7], ignore_index=True)
len(ulta_df7)
# Out:
# 672

# %%
ulta_df7.head()
# Out:
#                brand                                               name  \
# 0       It Cosmetics       Confidence In A Cream Anti-Aging Moisturizer
# 1           Clinique        Dramatically Different Moisturizing Lotion+
# 2  Peter Thomas Roth  Water Drench Hyaluronic Cloud Cream Hydrating ...
# 3             ELEMIS                          Pro-Collagen Marine Cream
# 4         StriVectin  SD Advanced Intensive Concentrate for Wrinkles...
#
#             price  rating                                        ingredients
# 0   Price\n$49.00     4.5                                                NaN
# 1   Price\n$29.50     4.3                                                NaN
# 2   Price\n$52.00     4.4  Water/Aqua/Eau, Glycerin, Dipropylene Glycol, ...
# 3  Price\n$128.00     4.5  Aqua/Water/Eau, Glycerin, Caprylic/Capric Trig...
# 4  Price\n$139.00     4.5  Aqua (Water, Eau), Glycerin, Pentaerythrityl T...

# %%
##USE THIS DATASET
combined_ulta_df=ulta_df7.copy()
combined_ulta_df.head()
# Out:
#                brand                                               name  \
# 0       It Cosmetics       Confidence In A Cream Anti-Aging Moisturizer
# 1           Clinique        Dramatically Different Moisturizing Lotion+
# 2  Peter Thomas Roth  Water Drench Hyaluronic Cloud Cream Hydrating ...
# 3             ELEMIS                          Pro-Collagen Marine Cream
# 4         StriVectin  SD Advanced Intensive Concentrate for Wrinkles...
#
#             price  rating                                        ingredients
# 0   Price\n$49.00     4.5                                                NaN
# 1   Price\n$29.50     4.3                                                NaN
# 2   Price\n$52.00     4.4  Water/Aqua/Eau, Glycerin, Dipropylene Glycol, ...
# 3  Price\n$128.00     4.5  Aqua/Water/Eau, Glycerin, Caprylic/Capric Trig...
# 4  Price\n$139.00     4.5  Aqua (Water, Eau), Glycerin, Pentaerythrityl T...

# %%
## USE THIS CSV NOW 

combined_ulta_df.to_csv('combined_ulta.csv', index = False)

# %%
## read new csv

new= pd.read_csv('combined_ulta.csv')
len(new)
# Out:
# 672

# %%
# combined_ulta_df.price.iloc[18]
# Out:
# 'Sale Price\n$15.19\nOriginal Price\n$18.99'

# %%
# # 1) look through "price" to find rows with string length greater than 8. Print value and row number. 
# #skin['price'] = skin['price'].astype(str)
# row=-1
# for x in combined_ulta_df['price']:
#     row+=1
#     if "Price\n$" in x:
#         print(x)
#         print(row)
# Out:
# Price
# $49.00
# 0
# Price
# $29.50
# 1
# Price
# $52.00
# 2
# Price
# $128.00
# 3
# Price
# $139.00
# 4
# Price
# $29.50
# 5
# Price
# $48.00
# 6
# Price
# $48.00
# 7
# Price
# $65.00
# 8
# Price
# $62.00
# 9
# Price
# $70.00
# 11
# Price
# $65.00
# 12
# Price
# $52.00
# 13
# Price
# $7.70
# 14
# Price
# $41.00
# 15
# Price
# $56.00
# 16
# Price
# $36.00
# 17
# Sale Price
# $15.19
# Original Price
# $18.99
# 18
# Price
# $69.00
# 19
# Sale Price
# $19.99
# Original Price
# $24.99
# 20
# Sale Price
# $15.19
# Original Price
# $18.99
# 21
# Price
# $32.00
# 22
# Price
# $29.50
# 23
# Price
# $69.00
# 24
# Sale Price
# $15.99
# Original Price
# $19.99
# 25
# Price
# $75.00
# 26
# Price
# $39.00
# 27
# Price
# $42.00
# 28
# Sale Price
# $15.19
# Original Price
# $18.99
# 29
# Price
# $41.00
# 30
# Price
# $32.00
# 31
# Sale Price
# $21.19
# Original Price
# $26.49
# 32
# Price
# $72.00
# 33
# Price
# $50.00
# 34
# Price
# $38.00
# 35
# Price
# $38.00
# 36
# Price
# $39.00
# 37
# Price
# ...

# %%
# # 2) find decimal and splice
# step=-1
# for x in combined_ulta_df['price']:
#     step+=1
#     if "Price\n$" in x:
#         find_n=combined_ulta_df.loc[step,'price'].find('n')
#         combined_ulta_df.loc[step,'price']= combined_ulta_df.loc[step,'price'][:(find_n+1)]

            
# combined_ulta_df.head()

# %%
# Out:
#                brand                                               name price  \
# 0       It Cosmetics       Confidence In A Cream Anti-Aging Moisturizer
# 1           Clinique        Dramatically Different Moisturizing Lotion+
# 2  Peter Thomas Roth  Water Drench Hyaluronic Cloud Cream Hydrating ...
# 3             ELEMIS                          Pro-Collagen Marine Cream
# 4         StriVectin  SD Advanced Intensive Concentrate for Wrinkles...
#
#    rating                                        ingredients
# 0     4.5                                                NaN
# 1     4.3                                                NaN
# 2     4.4  Water/Aqua/Eau, Glycerin, Dipropylene Glycol, ...
# 3     4.5  Aqua/Water/Eau, Glycerin, Caprylic/Capric Trig...
# 4     4.5  Aqua (Water, Eau), Glycerin, Pentaerythrityl T...
