# %% [markdown]
# In this notebook we webscrape Ulta's website.

# %%
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException 
import numpy as np

# %% [markdown]
# We set up a Chrome path that opens up the Ulta face moisturizer site.

# %%
### Get Chrome Driver Path 
path = r"C:\Users\avach\Downloads\clone\info2950\chromedriver.exe" 
driver = webdriver.Chrome(path) 

### Open Ulta Moisturizer Site
driver.get('https://www.ulta.com/skin-care-face-moisturizer?N=27h9')

# %%
all_prod = driver.find_element_by_xpath('//*[@id="product-category-cont"]')

html_list = all_prod.find_element_by_id("foo16")
all_li = html_list.find_elements_by_tag_name("li")

product_name = []
subpageurl = []


#append links for products to subpageurl list
for li in all_li: 
    first_atag = li.find_element_by_tag_name('a')
    product_links= first_atag.get_attribute('href')
    
#popup link, got rid of it 
    if product_links != 'http://www.ulta.com/ulta/creditcards/landingpage.jsp':
        subpageurl.append(product_links)
        
#get name of hyperlink, not actual link 

#https://sqa.stackexchange.com/questions/37024/how-do-i-get-the-text-of-a-hyperlink-not-the-actual-link-using-selenium-and-py (innerlink source)
        cut_text = first_atag.get_attribute('innerHTML')
        find_alt = cut_text.find('alt="')
        name = cut_text[find_alt+5:]
        find_border = name.find('" border=')
        name2 = name[:find_border]
        if '+' in name2: 
            plus = name2.find('+') 
            name2 = name2[:plus]
            
        product_name.append(name2)

# %%
brand_list = []
product_list = [] 
price_list = [] 
rating_list = []
ingredient_list = []

# %%
##loop to get info on first page 

for link in subpageurl:
    driver.get(link)  

    ## Get brand 
    try:
        brand_list.append(driver.find_element_by_xpath('//*[@id="js-mobileBody"]/div/div/div/div/div/div/section[1]/div[2]/div/h1/div[1]').text)
    except: 
        brand_list.append('NA')
    
    ### Get Product Name 
    try:
        product_list.append(driver.find_element_by_xpath('//*[@id="js-mobileBody"]/div/div/div/div/div/div/section[1]/div[2]/div/h1/div[2]').text)
    except: 
        product_list.append('NA')
     ### Get Price 
    try:
        price_list.append(driver.find_element_by_xpath('//*[@id="js-mobileBody"]/div/div/div/div/div/div/section[1]/div[2]/div/div[3]').text)
    except: 
        price_list.append('NA') 
        
    ### Get Rating Number 
    try: 
        rating_list.append(driver.find_element_by_xpath('//*[@id="pr-review-snapshot"]/header/section/div/div[1]/div/div[1]/div').text)
    except: 
        rating_list.append('NA')

    ### Once on product page, toggle ingredients and get text
    try:
        toggle = driver.find_element_by_xpath('//*[@id="productDescription"]/div[3]/div[2]')
        toggle.click() 

        ingredient_list.append(driver.find_element_by_xpath('//*[@id="productDescription"]/div[3]/div[2]/div[2]/div/div/div').text) 
    except:
        ingredient_list.append('NA')

# %%
rating_list
# Out:
# ['4.5',
#  '4.3',
#  '4.4',
#  '4.5',
#  '4.5',
#  '4.6',
#  '4.4',
#  '4.7',
#  '4.5',
#  '4.4',
#  '4.4',
#  '4.5',
#  '4.2',
#  '4.7',
#  'NA',
#  '4.2',
#  '4.6',
#  '4.4',
#  '3.3',
#  '4.5',
#  '4.6',
#  '4.4',
#  '4.6',
#  '4.1',
#  '4.2',
#  '4.3',
#  '4.6',
#  '4.6',
#  '4.5',
#  '4.5',
#  '3.3',
#  'NA',
#  '4.3',
#  '4.5',
#  '4.4',
#  '4.7',
#  '4.6',
#  '4.6',
#  '4.5',
#  '4.7',
#  '4.6',
#  '4.5',
#  '4.2',
#  '4.1',
#  '4.3',
#  '4.6',
#  '4.9',
#  '4.1',
#  '4',
#  '4.7',
#  '4.4',
#  '4.8',
#  '4.5',
#  '4.3',
#  '4.6',
#  '4.5',
#  'NA',
#  '4.3',
#  '3.3',
#  '4.6',
#  '4.5',
#  '4.3',
#  'NA',
#  '3.7',
#  'NA',
#  '4.5',
#  '4.4',
#  '4.3',
#  '4.3',
#  '4.6',
#  '4.6',
#  '4.7',
#  '4.9',
#  '4.5',
#  '3.9',
#  '4.4',
#  '4.4',
#  '4.1',
#  '4.3',
#  '4.3',
#  '4',
#  '4.5',
#  '4.3',
#  '4.8',
#  '4.8',
#  '4.6',
#  '4.3',
#  'NA',
#  '4.3',
#  '4.3',
#  '4.5',
#  '4.4',
#  '3.7',
#  '4.4',
#  '4.6',
#  '4.5',
#  'NA']

# %%
ulta_moisturizer_df = pd.DataFrame(
    {'brand': brand_list[:96],
     'name': product_list[:96],
     'price': price_list[:96],
     'rating': rating_list[:96],
     'ingredients': ingredient_list[:96]
    }) 

pd.set_option('display.max_rows',None)
ulta_moisturizer_df
#ulta_moisturizer_df_keep=ulta_moisturizer_df.copy()
# Out:
#                  brand                                               name  \
# 0         It Cosmetics       Confidence In A Cream Anti-Aging Moisturizer
# 1             Clinique        Dramatically Different Moisturizing Lotion+
# 2    Peter Thomas Roth  Water Drench Hyaluronic Cloud Cream Hydrating ...
# 3               ELEMIS                          Pro-Collagen Marine Cream
# 4           StriVectin  SD Advanced Intensive Concentrate for Wrinkles...
# 5             Clinique            Dramatically Different Moisturizing Gel
# 6             Shiseido                Essential Energy Moisturizing Cream
# 7              Lancôme                    Hydra Zen Anti-Stress Gel Cream
# 8                Murad  Essential-C Day Moisture Broad Spectrum SPF 30...
# 9                Murad                         Nutrient-Charged Water Gel
# 10        PEACH & LILY                   Matcha Pudding Antioxidant Cream
# 11        Juice Beauty             STEM CELLULAR Anti-Wrinkle Moisturizer
# 12          Philosophy  Anti-Wrinkle Miracle Worker+ Line Correcting M...
# 13                Tula          24-7 Moisture Hydrating Day & Night Cream
# 14        The Ordinary                  Natural Moisturizing Factors + HA
# 15             Origins  GinZing SPF 40 Energy-Boosting Tinted Moisturizer
# 16            Clinique  Moisture Surge 100 Hour Auto-Replenishing Hydr...
# 17    First Aid Beauty                                 Ultra Repair Cream
# 18              CeraVe               AM Facial Moisturizing Lotion SPF 30
# 19        Perricone MD  High Potency Classics: Face Finishing & Firmin...
# 20              CeraVe                                           SA Cream
# 21              CeraVe                   SA Lotion For Rough & Bumpy Skin
# 22  Kiehl's Since 1851                                 Ultra Facial Cream
# 23            Clinique             Dramatically Different Hydrating Jelly
# 24        It Cosmetics  Hello Results Wrinkle-Reducing Daily Retinol S...
# 25      La Roche-Posay  Toleriane Double Repair Face Moisturizer UV SP...
# 26         Dermalogica        Dynamic Skin Recovery Broad Spectrum SPF 50
# 27          Philosophy  Renewed Hope in a Jar Water Cream Hyaluronic G...
# 28         Dermalogica                                       Active Moist
# 29              CeraVe             Ultra-Light Moisturizing Lotion SPF 30
# 30            Clinique  Moisture Surge Intense 72H Lipid-Replenishing ...
# 31               COSRX                      Full Fit Propolis Light Cream
# 32          Neutrogena                              Hydro Boost Water Gel
# 33         Dermalogica                         Intensive Moisture Balance
# 34            Clinique  Redness Solutions Daily Relief Cream With Prob...
# 35               belif                   The True Cream-Moisturizing Bomb
# 36               belif                           The True Cream-Aqua Bomb
# 37          Philosophy  Renewed Hope In A Jar Refreshing & Refining Mo...
# 38         Dermalogica                               Skin Smoothing Cream
# 39         Dermalogica                        Age Smart Super Rich Repair
# 40      La Roche-Posay         Cicaplast Baume B5 Soothing Repairing Balm
# 41                 No7  Restore & Renew Face & Neck Multi Action Day C...
# 92            Clinique             Derm Pro Solutions: For Aging Skin Set
# 93             Hanskin                            Hyaluron Moisture Cream
# 94   Benefit Cosmetics                        Total Moisture Facial Cream
# 95            Clinique  Repairwear Laser Focus Wrinkle Correcting Eye ...
#
#                                          price rating  \
# 0                                Price\n$49.00    4.5
# 1                                Price\n$29.50    4.3
# 2                                Price\n$52.00    4.4
# 3                               Price\n$128.00    4.5
# 4                               Price\n$139.00    4.5
# 5                                Price\n$29.50    4.6
# 6                                Price\n$48.00    4.4
# 7                                Price\n$48.00    4.7
# 8                                Price\n$65.00    4.5
# 9                                Price\n$62.00    4.4
# 10                         Only at Ulta Beauty    4.4
# 11                               Price\n$70.00    4.5
# 12                               Price\n$65.00    4.2
# 13                               Price\n$52.00    4.7
# 14                                Price\n$7.70     NA
# 15                               Price\n$41.00    4.2
# 16                               Price\n$56.00    4.6
# 17                               Price\n$36.00    4.4
# 18  Sale Price\n$15.19\nOriginal Price\n$18.99    3.3
# 19                               Price\n$69.00    4.5
# 20  Sale Price\n$19.99\nOriginal Price\n$24.99    4.6
# 21  Sale Price\n$15.19\nOriginal Price\n$18.99    4.4
# 22                               Price\n$32.00    4.6
# 23                               Price\n$29.50    4.1
# 24                               Price\n$69.00    4.2
# 25  Sale Price\n$15.99\nOriginal Price\n$19.99    4.3
# 26                               Price\n$75.00    4.6
# 27                               Price\n$39.00    4.6
# 28                               Price\n$42.00    4.5
# 29  Sale Price\n$15.19\nOriginal Price\n$18.99    4.5
# 30                               Price\n$41.00    3.3
# 31                               Price\n$32.00     NA
# 32  Sale Price\n$21.19\nOriginal Price\n$26.49    4.3
# 33                               Price\n$72.00    4.5
# 34                               Price\n$50.00    4.4
# 35                               Price\n$38.00    4.7
# 36                               Price\n$38.00    4.6
# 37                               Price\n$39.00    4.6
# 38                               Price\n$69.00    4.5
# 39                               Price\n$89.00    4.7
# 40                               Price\n$14.99    4.6
# 41  Sale Price\n$18.89\nOriginal Price\n$26.99    4.5
# 42                               Price\n$28.00    4.2
# 43  Sale Price\n$15.99\nOriginal Price\n$19.99    4.1
# 44                               Price\n$42.00    4.3
# 45  Sale Price\n$21.19\nOriginal Price\n$26.49    4.6
# 46                               Price\n$44.00    4.9
# 47                               Price\n$88.00    4.1
# 48                               Price\n$34.00      4
# 49                              Price\n$109.00    4.7
# 50  Sale Price\n$27.29\nOriginal Price\n$38.99    4.4
# 51  Sale Price\n$16.80\nOriginal Price\n$24.00    4.8
# 52   Sale Price\n$8.40\nOriginal Price\n$12.00    4.5
# 53  Sale Price\n$18.89\nOriginal Price\n$26.99    4.3
# 54  Sale Price\n$20.29\nOriginal Price\n$28.99    4.6
# 55  Sale Price\n$23.99\nOriginal Price\n$29.99    4.5
# 56                               Price\n$58.00     NA
# 57                               Price\n$58.00    4.3
# 58                               Price\n$26.00    3.3
# 59                               Price\n$50.00    4.6
# 60                               Price\n$54.00    4.5
# 61  Sale Price\n$27.19\nOriginal Price\n$33.99    4.3
# 62                               Price\n$35.00     NA
# 63                               Price\n$28.00    3.7
# 64                               Price\n$16.00     NA
# 65                               Price\n$78.00    4.5
# 79  Water\Aqua\Eau, Butylene Glycol, Dicaprylyl Ca...
# 80  Active: AvobenzoneM3.0%, Homosalate 10.0%, Oct...
# 81  Active: Salicylic Acid 2%.\nInactive: Aqua/Wat...
# 82  Active: Avobenzone 3.0%, Octisalate 5.0%.\n\nI...
# 83  Active: Avobenzone 2.20%, Octinoxate 7.50%.\nI...
# 84  Water / Aqua / Eau, Glycerin, Dimethicone, Pet...
# 85  Active: Avobenzone 3%, Octisalate 5%, Octocryl...
# 86  Water, Aloe (Aloe Barbadensis Leaf Juice), Cet...
# 87  Aqua / Water / Eau, Glycerin, Cyclohexasiloxan...
# 88  Active Ingredients: Avobenzone (2.7%), Octinox...
# 89
# 90  Aqua (Water), C12-15 Alkyl Benzoate, Glycerin,...
# 91  Water\Aqua\Eau, Glycerin, Dimethicone, Isoprop...
# 92                                                 NA
# 93  Water, Glycerin, Butylene Glycol, Alcohol Dena...
# 94  Water (Aqua), Dicaprylyl Carbonate, Hydrogenat...
# 95  Water / Aqua / Eau, Squalane, Butylene Glycol,...

# %%
print(len(brand_list))
print(len(product_list))
print(len(price_list))
print(len(rating_list))
print(len(ingredient_list))
# Out:
# 97
# 97
# 97
# 97
# 97

# %%
ulta_moisturizer_df.to_csv('ulta_m1.csv', index = False)

# %%
### Find first product and click to open 
#prod = driver.find_element_by_xpath('//*[@id="xlsImpprod13641053"]/div[2]') 
#prod.click()

# %%
### Get brand
# brand = driver.find_element_by_xpath('//*[@id="js-mobileBody"]/div/div/div/div/div/div/section[1]/div[2]/div/h1/div[1]').text
# print(brand)

# ### Get Product Name 
# name = driver.find_element_by_xpath('//*[@id="js-mobileBody"]/div/div/div/div/div/div/section[1]/div[2]/div/h1/div[2]').text
# print(name) 
 

# ### Get Rating Number
# star = driver.find_element_by_xpath('//*[@id="pr-review-snapshot"]/header/section/div/div[1]/div/div[1]/div').text
# print(star) 

# ### Once on product page, toggle ingredients and get text
# toggle = driver.find_element_by_xpath('//*[@id="productDescription"]/div[3]/div[2]')
# toggle.click() 

# ingredient = driver.find_element_by_xpath('//*[@id="productDescription"]/div[3]/div[2]/div[2]/div/div/div').text
# print(ingredient) 

# ### Get Price 
# price = driver.find_element_by_xpath('//*[@id="js-mobileBody"]/div/div/div/div/div/div/section[1]/div[2]/div/div[3]').text
# print(price)

# %%
# def scrollDown(driver, n_scroll):

#     body = driver.find_element_by_tag_name("body")
#     while n_scroll >= 0:
#         body.send_keys(Keys.PAGE_DOWN)
#         n_scroll -= 1
#     return driver

# %%
##next steps 

#move into data frame 
#scrol through each of the 14 pages

# %%
ulta_m1 = pd.read_csv('ulta_m1.csv')

# %%
ulta_m1.head()
# Out:
#                brand                                               name  \
# 0       It Cosmetics       Confidence In A Cream Anti-Aging Moisturizer
# 1           Clinique        Dramatically Different Moisturizing Lotion+
# 2  Peter Thomas Roth  Water Drench Hyaluronic Cloud Cream Hydrating ...
# 3             ELEMIS                          Pro-Collagen Marine Cream
# 4         StriVectin  SD Advanced Intensive Concentrate for Wrinkles...
#
#             price  rating                                        ingredients
# 0   Price\n$49.00     4.5                                                NaN
# 1   Price\n$29.50     4.3                                                NaN
# 2   Price\n$52.00     4.4  Water/Aqua/Eau, Glycerin, Dipropylene Glycol, ...
# 3  Price\n$128.00     4.5  Aqua/Water/Eau, Glycerin, Caprylic/Capric Trig...
# 4  Price\n$139.00     4.5  Aqua (Water, Eau), Glycerin, Pentaerythrityl T...
